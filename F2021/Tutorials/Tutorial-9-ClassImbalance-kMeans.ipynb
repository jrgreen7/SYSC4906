# %% [markdown]
# # Tutorial 9 - Class Imbalance & k-Means
#
# **Semester:** Fall 2021
#
# **Adapted by:** [Kevin Dick](https://kevindick.ai/)
#
# **Part I adapted from:** [Scikit-Learn's Plot Classifier Performance](https://scikit-learn.org/0.15/auto_examples/plot_classifier_comparison.html).
#
# **Part II adapted from:** Andrew Yue Xie's [K-Means Clustering Implementation in Python](https://www.kaggle.com/andyxie/k-means-clustering-implementation-in-python)
#
# ---
#
#
#
# ## 1. Introduction
# In this notebook, we will explore four different classifiers and how they perform on artificial datasets with linear and nonlinear class distributions, as the class imbalance changes from 1:1 to 1:100. We are most interested in how the decision boundaries change between various classifiers. We will then explore under-sampling as a way to solve the issue.
#
# <i>Note that this Notebook is based on https://scikit-learn.org/0.15/auto_examples/plot_classifier_comparison.html</i>
#
# The classifiers we will be looking at are:
# - Logistic regression
# - Decision tree
# - linear SVM
# - SVM with a nonlinear kernel
# - K-Nearest-Neighbour <i>(yes, neighbour has a 'u'...)</i>
#
# Scikit-learn has a powerful toolboxes for building classifiers, creating artificial data, and visualizing decision boundaries. The toolboxes can be seen in the import calls below.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
import seaborn as sb

# %% [markdown]
# We import these packages, but as usual we will also need numpy and matplotlib. Let's import those packages now.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## 2. The Data
#
# Generate datasets with 1:1 class imbalance. Increase this to 1:10 and 1:100.

# %%
# Create 4 datasets of varying class imbalance:

# 1) Dataset where classes are distributed in moons
allX, ally = make_moons(noise=0.2, random_state=1, n_samples=20000)
allX_1 = allX[ally==1]
allX_0 = allX[ally==0]
ally_1 = ally[ally==1]
ally_0 = ally[ally==0]

numClass0 = 10 #1000:1
X1000 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y1000 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

numClass0 = 100 #100:1
X100 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y100 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

numClass0 = 1000 #10:1
X10 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y10 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

numClass0 = 10000 #1:1
X1 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y1 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

# Gather all four datasets
datasets = [(X1000,y1000),
            (X100,y100),
            (X10,y10),
            (X1,y1)]

dataset_names= ["1000:1", "100:1", "10:1", "1:1"]

## Visualize the datasets

#Plot 1000:1 data
plt.figure(figsize= (12,12))
plt.subplot(2, 2, 1)
plt.scatter(X1000[0:,0], X1000[0:,1], c=y1000)
plt.title(dataset_names[0])

#Plot Circles data
plt.subplot(2, 2, 2)
plt.scatter(X100[0:,0], X100[0:,1], c=y100)
plt.title(dataset_names[1])

#Plot Linearly separable
plt.subplot(2, 2, 3)
plt.scatter(X10[0:,0], X10[0:,1], c=y10)
plt.title(dataset_names[2])

#Plot Linearly separable
plt.subplot(2, 2, 4)
plt.scatter(X1[0:,0], X1[0:,1], c=y1)
plt.title(dataset_names[3]);  #(adding semi-colon suppresses output of text "Noisy Linearly Separable")

# %% [markdown]
# We've had a look at the data, now let's prepare our classifiers so that we can later evaluate how they perform on each dataset.

# %%
classifierNames = ["Logistic Regression", "Decision Tree", "Linear SVM", "RBF SVM","KNN"]

classifiers = [
    LogisticRegression(solver='lbfgs'), #Logistic regression
    DecisionTreeClassifier(max_depth=5), #Decision tree classifier with max_depth=5
    SVC(kernel="linear", C=0.025), #Linear SVM classifier
    SVC(kernel= 'rbf', gamma=2, C=1.0), # SVM with radial basis function kernel, gamma is kernel coefficient, C is penalty parameter for misclassified points
    KNeighborsClassifier(3)]

# %% [markdown]
# ## 3. Classifier Performance
#
# In this section, we will visualize the decision boundary for each classifier and compute the accuracy for each classifier on each dataset. We will follow the same training and testing protocol as in the CarsRegression notebook.

# %%
from sklearn.metrics import classification_report

h = .02  # Resolution in colored mesh visualizations
i= 1
figure = plt.figure(figsize=(27, 9))
j= 0


for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Set plot axis limits
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    
    # Prepare some nice visualizations
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    
    # Plot the datasets in first column
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i, title=dataset_names[j])
    j+= 1
    # Plot the training points 
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
    
    # Plot the testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6)
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1
    
    # Iterate over classifiers ('zip' iterates through two equal-length lists simultaneously)
    for name, clf in zip(classifierNames, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
        
        # Train and test our classifier
        clf.fit(X_train, y_train) # create classification model using training data
        score = clf.score(X_test, y_test) # evaluate classifier on the testing set

        # Plot the decision boundary. For that, we will assign a color to each point in the mesh [x_min, m_max]x[y_min, y_max].
        if hasattr(clf, "decision_function"):
            # flatten xx and yy to 1D arrays and get decision function, or decision boundary hyperplane
            Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()]) 
        else:
            # if no decision function available, use prediction probability as contrast for contour lines
            Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1] 

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

        # Plot the training points
        #ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
        
        # Plot the testing points (use alpha=0.6 to make them slightly transparent)
        ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright,
                   alpha=0.6)

        # Set axes limits
        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())

        # Add a title and overlay the prediction score onto the bottom-right corner of the plot
        ax.set_title(name)
        ax.text(xx.max() - .3, yy.min() + .3, ('%.3f' % score).lstrip('0'),
                size=15, horizontalalignment='right')
        i += 1

figure.subplots_adjust(left=.02, right=.98)
plt.show()

# %%
from sklearn.metrics import classification_report
j= 0

for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Look at Logistic Regression:
    name = classifierNames[0]
    clf = classifiers[0]

    # Train and test our classifier
    clf.fit(X_train, y_train) # create classification model using training data
    i += 1

    # Accuracy on the plot is not telling the whole story. Print classification report
    y_pred = clf.predict(X_test)
    target_names = ['red', 'blue']
    print(dataset_names[j])
    print(classification_report(y_test, y_pred, target_names=target_names))
    j+=1
# Out:
# 1000:1
#               precision    recall  f1-score   support
#
#          red       0.00      0.00      0.00         3
#         blue       1.00      1.00      1.00      3000
#
#     accuracy                           1.00      3003
#    macro avg       0.50      0.50      0.50      3003
# weighted avg       1.00      1.00      1.00      3003
#
# 100:1
#               precision    recall  f1-score   support
#
#          red       1.00      0.25      0.40        24
#         blue       0.99      1.00      1.00      3006
#
#     accuracy                           0.99      3030
#    macro avg       1.00      0.62      0.70      3030
# weighted avg       0.99      0.99      0.99      3030
#
# 10:1
#               precision    recall  f1-score   support
#
#          red       0.78      0.57      0.66       300
#         blue       0.96      0.98      0.97      3000
#
#     accuracy                           0.95      3300
#    macro avg       0.87      0.78      0.82      3300
# weighted avg       0.94      0.95      0.94      3300
#
# 1:1
#               precision    recall  f1-score   support
#
#          red       0.87      0.87      0.87      3010
#         blue       0.87      0.87      0.87      2990
#
#     accuracy                           0.87      6000
#    macro avg       0.87      0.87      0.87      6000
# weighted avg       0.87      0.87      0.87      6000
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# code modified from: https://scikit-learn.org/0.15/auto_examples/plot_classifier_comparison.html
#
# ## 4. Discussion
#
# - What did the full classification report show that the accuracy in the plots did not?
# - How would you address the class imbalance?
#
# ## 5. Try Subsampling of Majority (blue) Class to Achieve "Balanced Training Set"

# %%
# Try subsampling from the dominant class to achieve 1:1 balance in training only

from sklearn.metrics import classification_report
j= 0

for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Apply subsampling:
    X_train_1 = X_train[y_train==1]
    X_train_0 = X_train[y_train==0]
    y_train_1 = y_train[y_train==1]
    y_train_0 = y_train[y_train==0]
    numClass0 = len(X_train)-sum(y_train)
    imbalance = len(X_train_1)/len(X_train_0)
    print("For dataset {0:d}, numClass0={1:d}, imbalance={2:.1f}".format(j,numClass0,round(imbalance)))
    X_train_SS = np.concatenate((X_train_0,X_train_1[:numClass0,:]),axis=0) 
    y_train_SS = np.concatenate((y_train_0, y_train_1[:numClass0]),axis=0) 

    ### Really should shuffle the dataset since it is now organized by classID...
    assert len(X_train_SS) == len(y_train_SS)
    p = np.random.permutation(len(X_train_SS))
    X_train_SS =  X_train_SS[p]
    y_train_SS = y_train_SS[p]
    print(f'Num in Subsampled: {len(X_train_SS)}')

    # Look at Logistic Regression:
    name = classifierNames[0]
    clf = classifiers[0]

    # Train and test our classifier
    clf.fit(X_train_SS, y_train_SS) # create classification model using training data

    # Print classification report
    y_pred = clf.predict(X_test)
    target_names = ['red', 'blue']
    print(dataset_names[j])
    print(classification_report(y_test, y_pred, target_names=target_names))
    j+=1
# Out:
# For dataset 0, numClass0=9, imbalance=778.0
# Num in Subsampled: 18
# 1000:1
#               precision    recall  f1-score   support
#
#          red       0.00      1.00      0.00         1
#         blue       1.00      0.83      0.91      3002
#
#     accuracy                           0.83      3003
#    macro avg       0.50      0.92      0.46      3003
# weighted avg       1.00      0.83      0.91      3003
#
# For dataset 1, numClass0=65, imbalance=108.0
# Num in Subsampled: 130
# 100:1
#               precision    recall  f1-score   support
#
#          red       0.06      0.86      0.12        35
#         blue       1.00      0.85      0.92      2995
#
#     accuracy                           0.85      3030
#    macro avg       0.53      0.85      0.52      3030
# weighted avg       0.99      0.85      0.91      3030
#
# For dataset 2, numClass0=699, imbalance=10.0
# Num in Subsampled: 1398
# 10:1
#               precision    recall  f1-score   support
#
#          red       0.40      0.85      0.54       301
#         blue       0.98      0.87      0.92      2999
#
#     accuracy                           0.87      3300
#    macro avg       0.69      0.86      0.73      3300
# weighted avg       0.93      0.87      0.89      3300
#
# For dataset 3, numClass0=6969, imbalance=1.0
# Num in Subsampled: 13938
# 1:1
#               precision    recall  f1-score   support
#
#          red       0.86      0.88      0.87      3031
#         blue       0.87      0.85      0.86      2969
#
#     accuracy                           0.87      6000
#    macro avg       0.87      0.87      0.87      6000
# weighted avg       0.87      0.87      0.87      6000

# %% [markdown]
# ##6. Try Over-sampling the Rare (red) Class to Achieve a "Balanced Training Set"

# %%
# Try over-sampling from the rare class (red) to achieve 1:1 balance in training only

from sklearn.metrics import classification_report
j= 0

for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Apply subsampling:
    X_train_1 = X_train[y_train==1]
    X_train_0 = X_train[y_train==0]
    y_train_1 = y_train[y_train==1]
    y_train_0 = y_train[y_train==0]
    numClass0 = len(X_train)-sum(y_train)
    imbalance = len(X_train_1)/len(X_train_0)
    print("For dataset {0:d}, numClass0={1:d}, imbalance={2:.1f}".format(j,numClass0,round(imbalance)))

    # To over-sample, add 'imbalance' copies of class 0 data:
    X_train_OS = X_train_1 
    y_train_OS = y_train_1 
    for k in range(round(imbalance)):
      X_train_OS = np.concatenate((X_train_OS,X_train_0),axis=0) 
      y_train_OS = np.concatenate((y_train_OS,y_train_0),axis=0) 
      print(f'Num in Oversampled: {len(X_train_OS)}')

    ### Really should shuffle the dataset since it is now organized by classID...
    assert len(X_train_OS) == len(y_train_OS)
    p = np.random.permutation(len(X_train_OS))
    X_train_OS =  X_train_OS[p]
    y_train_OS = y_train_OS[p]

    # Look at Logistic Regression:
    name = classifierNames[0]
    clf = classifiers[0]

    # Train and test our classifier
    clf.fit(X_train_OS, y_train_OS) # create classification model using training data

    # Print classification report
    y_pred = clf.predict(X_test)
    target_names = ['red', 'blue']
    print(dataset_names[j])
    print(classification_report(y_test, y_pred, target_names=target_names))
    j+=1
# Out:
# For dataset 0, numClass0=7, imbalance=1000.0
# Num in Oversampled: 7007
# Num in Oversampled: 7014
# Num in Oversampled: 7021
# Num in Oversampled: 7028
# Num in Oversampled: 7035
# Num in Oversampled: 7042
# Num in Oversampled: 7049
# Num in Oversampled: 7056
# Num in Oversampled: 7063
# Num in Oversampled: 7070
# Num in Oversampled: 7077
# Num in Oversampled: 7084
# Num in Oversampled: 7091
# Num in Oversampled: 7098
# Num in Oversampled: 7105
# Num in Oversampled: 7112
# Num in Oversampled: 7119
# Num in Oversampled: 7126
# Num in Oversampled: 7133
# Num in Oversampled: 7140
# Num in Oversampled: 7147
# Num in Oversampled: 7154
# Num in Oversampled: 7161
# Num in Oversampled: 7168
# Num in Oversampled: 7175
# Num in Oversampled: 7182
# Num in Oversampled: 7189
# Num in Oversampled: 7196
# Num in Oversampled: 7203
# Num in Oversampled: 7210
# Num in Oversampled: 7217
# Num in Oversampled: 7224
# Num in Oversampled: 7231
# Num in Oversampled: 7238
# Num in Oversampled: 7245
# Num in Oversampled: 7252
# Num in Oversampled: 7259
# Num in Oversampled: 7266
# Num in Oversampled: 7273
# Num in Oversampled: 7280
# Num in Oversampled: 7287
# Num in Oversampled: 7294
# Num in Oversampled: 7301
# Num in Oversampled: 7308
# Num in Oversampled: 7315
# Num in Oversampled: 7322
# Num in Oversampled: 7329
# Num in Oversampled: 7336
# Num in Oversampled: 7343
# Num in Oversampled: 7350
# Num in Oversampled: 7357
# Num in Oversampled: 7364
# Num in Oversampled: 7371
# Num in Oversampled: 7378
# Num in Oversampled: 7385
# Num in Oversampled: 7392
# Num in Oversampled: 7399
# Num in Oversampled: 7406
# Num in Oversampled: 7413
# Num in Oversampled: 7420
# Num in Oversampled: 7427
# Num in Oversampled: 7434
# Num in Oversampled: 7441
# Num in Oversampled: 7448
# Num in Oversampled: 7455
# Num in Oversampled: 7462
# Num in Oversampled: 7469
# Num in Oversampled: 7476
# Num in Oversampled: 7483
# Num in Oversampled: 7490
# Num in Oversampled: 7497
# Num in Oversampled: 7504
# Num in Oversampled: 7511
# Num in Oversampled: 7518
# Num in Oversampled: 7525
# Num in Oversampled: 7532
# Num in Oversampled: 7539
# Num in Oversampled: 7546
# Num in Oversampled: 7553
# Num in Oversampled: 7560
# Num in Oversampled: 7567
# Num in Oversampled: 7574
# Num in Oversampled: 7581
# Num in Oversampled: 7588
# Num in Oversampled: 7595
# Num in Oversampled: 7602
# Num in Oversampled: 7609
# Num in Oversampled: 7616
# Num in Oversampled: 7623
# Num in Oversampled: 7630
# Num in Oversampled: 7637
# Num in Oversampled: 7644
# Num in Oversampled: 7651
# Num in Oversampled: 7658
# Num in Oversampled: 7665
# Num in Oversampled: 7672
# Num in Oversampled: 7679
# Num in Oversampled: 7686
# Num in Oversampled: 7693
# Num in Oversampled: 7700
# Num in Oversampled: 7707
# Num in Oversampled: 7714
# Num in Oversampled: 7721
# Num in Oversampled: 7728
# Num in Oversampled: 7735
# Num in Oversampled: 7742
# Num in Oversampled: 7749
# Num in Oversampled: 7756
# Num in Oversampled: 7763
# Num in Oversampled: 7770
# Num in Oversampled: 7777
# Num in Oversampled: 7784
# Num in Oversampled: 7791
# Num in Oversampled: 7798
# Num in Oversampled: 7805
# Num in Oversampled: 7812
# Num in Oversampled: 7819
# Num in Oversampled: 7826
# Num in Oversampled: 7833
# Num in Oversampled: 7840
# Num in Oversampled: 7847
# Num in Oversampled: 7854
# Num in Oversampled: 7861
# Num in Oversampled: 7868
# Num in Oversampled: 7875
# Num in Oversampled: 7882
# Num in Oversampled: 7889
# Num in Oversampled: 7896
# Num in Oversampled: 7903
# Num in Oversampled: 7910
# Num in Oversampled: 7917
# Num in Oversampled: 7924
# Num in Oversampled: 7931
# Num in Oversampled: 7938
# Num in Oversampled: 7945
# Num in Oversampled: 7952
# Num in Oversampled: 7959
# Num in Oversampled: 7966
# Num in Oversampled: 7973
# Num in Oversampled: 7980
# Num in Oversampled: 7987
# Num in Oversampled: 7994
# Num in Oversampled: 8001
# Num in Oversampled: 8008
# Num in Oversampled: 8015
# Num in Oversampled: 8022
# Num in Oversampled: 8029
# Num in Oversampled: 8036
# Num in Oversampled: 8043
# Num in Oversampled: 8050
# Num in Oversampled: 8057
# Num in Oversampled: 8064
# Num in Oversampled: 8071
# Num in Oversampled: 8078
# Num in Oversampled: 8085
# Num in Oversampled: 8092
# Num in Oversampled: 8099
# Num in Oversampled: 8106
# Num in Oversampled: 8113
# Num in Oversampled: 8120
# Num in Oversampled: 8127
# Num in Oversampled: 8134
# Num in Oversampled: 8141
# Num in Oversampled: 8148
# Num in Oversampled: 8155
# Num in Oversampled: 8162
# Num in Oversampled: 8169
# Num in Oversampled: 8176
# Num in Oversampled: 8183
# Num in Oversampled: 8190
# Num in Oversampled: 8197
# Num in Oversampled: 8204
# Num in Oversampled: 8211
# Num in Oversampled: 8218
# Num in Oversampled: 8225
# Num in Oversampled: 8232
# Num in Oversampled: 8239
# Num in Oversampled: 8246
# Num in Oversampled: 8253
# Num in Oversampled: 8260
# Num in Oversampled: 8267
# Num in Oversampled: 8274
# Num in Oversampled: 8281
# Num in Oversampled: 8288
# Num in Oversampled: 8295
# Num in Oversampled: 8302
# Num in Oversampled: 8309
# Num in Oversampled: 8316
# Num in Oversampled: 8323
# Num in Oversampled: 8330
# Num in Oversampled: 8337
# Num in Oversampled: 8344
# Num in Oversampled: 8351
# Num in Oversampled: 8358
# Num in Oversampled: 8365
# Num in Oversampled: 8372
# Num in Oversampled: 8379
# Num in Oversampled: 8386
# Num in Oversampled: 8393
# Num in Oversampled: 8400
# Num in Oversampled: 8407
# Num in Oversampled: 8414
# Num in Oversampled: 8421
# Num in Oversampled: 8428
# Num in Oversampled: 8435
# Num in Oversampled: 8442
# Num in Oversampled: 8449
# Num in Oversampled: 8456
# Num in Oversampled: 8463
# Num in Oversampled: 8470
# Num in Oversampled: 8477
# Num in Oversampled: 8484
# Num in Oversampled: 8491
# Num in Oversampled: 8498
# Num in Oversampled: 8505
# Num in Oversampled: 8512
# Num in Oversampled: 8519
# Num in Oversampled: 8526
# Num in Oversampled: 8533
# Num in Oversampled: 8540
# Num in Oversampled: 8547
# Num in Oversampled: 8554
# Num in Oversampled: 8561
# Num in Oversampled: 8568
# Num in Oversampled: 8575
# Num in Oversampled: 8582
# Num in Oversampled: 8589
# Num in Oversampled: 8596
# Num in Oversampled: 8603
# Num in Oversampled: 8610
# Num in Oversampled: 8617
# Num in Oversampled: 8624
# Num in Oversampled: 8631
# Num in Oversampled: 8638
# Num in Oversampled: 8645
# Num in Oversampled: 8652
# Num in Oversampled: 8659
# Num in Oversampled: 8666
# Num in Oversampled: 8673
# Num in Oversampled: 8680
# Num in Oversampled: 8687
# Num in Oversampled: 8694
# Num in Oversampled: 8701
# Num in Oversampled: 8708
# Num in Oversampled: 8715
# Num in Oversampled: 8722
# Num in Oversampled: 8729
# Num in Oversampled: 8736
# Num in Oversampled: 8743
# Num in Oversampled: 8750
# Num in Oversampled: 8757
# Num in Oversampled: 8764
# Num in Oversampled: 8771
# Num in Oversampled: 8778
# Num in Oversampled: 8785
# Num in Oversampled: 8792
# Num in Oversampled: 8799
# Num in Oversampled: 8806
# Num in Oversampled: 8813
# Num in Oversampled: 8820
# Num in Oversampled: 8827
# Num in Oversampled: 8834
# Num in Oversampled: 8841
# Num in Oversampled: 8848
# Num in Oversampled: 8855
# Num in Oversampled: 8862
# Num in Oversampled: 8869
# Num in Oversampled: 8876
# Num in Oversampled: 8883
# Num in Oversampled: 8890
# Num in Oversampled: 8897
# Num in Oversampled: 8904
# Num in Oversampled: 8911
# Num in Oversampled: 8918
# Num in Oversampled: 8925
# Num in Oversampled: 8932
# Num in Oversampled: 8939
# Num in Oversampled: 8946
# Num in Oversampled: 8953
# Num in Oversampled: 8960
# Num in Oversampled: 8967
# Num in Oversampled: 8974
# Num in Oversampled: 8981
# Num in Oversampled: 8988
# Num in Oversampled: 8995
# Num in Oversampled: 9002
# Num in Oversampled: 9009
# Num in Oversampled: 9016
# Num in Oversampled: 9023
# Num in Oversampled: 9030
# Num in Oversampled: 9037
# Num in Oversampled: 9044
# Num in Oversampled: 9051
# Num in Oversampled: 9058
# Num in Oversampled: 9065
# Num in Oversampled: 9072
# Num in Oversampled: 9079
# Num in Oversampled: 9086
# Num in Oversampled: 9093
# Num in Oversampled: 9100
# Num in Oversampled: 9107
# Num in Oversampled: 9114
# Num in Oversampled: 9121
# Num in Oversampled: 9128
# Num in Oversampled: 9135
# Num in Oversampled: 9142
# Num in Oversampled: 9149
# Num in Oversampled: 9156
# Num in Oversampled: 9163
# Num in Oversampled: 9170
# Num in Oversampled: 9177
# Num in Oversampled: 9184
# Num in Oversampled: 9191
# Num in Oversampled: 9198
# Num in Oversampled: 9205
# Num in Oversampled: 9212
# Num in Oversampled: 9219
# Num in Oversampled: 9226
# Num in Oversampled: 9233
# Num in Oversampled: 9240
# Num in Oversampled: 9247
# Num in Oversampled: 9254
# Num in Oversampled: 9261
# Num in Oversampled: 9268
# Num in Oversampled: 9275
# Num in Oversampled: 9282
# Num in Oversampled: 9289
# Num in Oversampled: 9296
# Num in Oversampled: 9303
# Num in Oversampled: 9310
# Num in Oversampled: 9317
# Num in Oversampled: 9324
# Num in Oversampled: 9331
# Num in Oversampled: 9338
# Num in Oversampled: 9345
# Num in Oversampled: 9352
# Num in Oversampled: 9359
# Num in Oversampled: 9366
# Num in Oversampled: 9373
# Num in Oversampled: 9380
# Num in Oversampled: 9387
# Num in Oversampled: 9394
# Num in Oversampled: 9401
# Num in Oversampled: 9408
# Num in Oversampled: 9415
# Num in Oversampled: 9422
# Num in Oversampled: 9429
# Num in Oversampled: 9436
# Num in Oversampled: 9443
# Num in Oversampled: 9450
# Num in Oversampled: 9457
# Num in Oversampled: 9464
# Num in Oversampled: 9471
# Num in Oversampled: 9478
# Num in Oversampled: 9485
# Num in Oversampled: 9492
# Num in Oversampled: 9499
# Num in Oversampled: 9506
# Num in Oversampled: 9513
# Num in Oversampled: 9520
# Num in Oversampled: 9527
# Num in Oversampled: 9534
# Num in Oversampled: 9541
# Num in Oversampled: 9548
# Num in Oversampled: 9555
# Num in Oversampled: 9562
# Num in Oversampled: 9569
# Num in Oversampled: 9576
# Num in Oversampled: 9583
# Num in Oversampled: 9590
# Num in Oversampled: 9597
# Num in Oversampled: 9604
# Num in Oversampled: 9611
# Num in Oversampled: 9618
# Num in Oversampled: 9625
# Num in Oversampled: 9632
# Num in Oversampled: 9639
# Num in Oversampled: 9646
# Num in Oversampled: 9653
# Num in Oversampled: 9660
# Num in Oversampled: 9667
# Num in Oversampled: 9674
# Num in Oversampled: 9681
# Num in Oversampled: 9688
# Num in Oversampled: 9695
# Num in Oversampled: 9702
# Num in Oversampled: 9709
# Num in Oversampled: 9716
# Num in Oversampled: 9723
# Num in Oversampled: 9730
# Num in Oversampled: 9737
# Num in Oversampled: 9744
# Num in Oversampled: 9751
# Num in Oversampled: 9758
# Num in Oversampled: 9765
# Num in Oversampled: 9772
# Num in Oversampled: 9779
# Num in Oversampled: 9786
# Num in Oversampled: 9793
# Num in Oversampled: 9800
# Num in Oversampled: 9807
# Num in Oversampled: 9814
# Num in Oversampled: 9821
# Num in Oversampled: 9828
# Num in Oversampled: 9835
# Num in Oversampled: 9842
# Num in Oversampled: 9849
# Num in Oversampled: 9856
# Num in Oversampled: 9863
# Num in Oversampled: 9870
# Num in Oversampled: 9877
# Num in Oversampled: 9884
# Num in Oversampled: 9891
# Num in Oversampled: 9898
# Num in Oversampled: 9905
# Num in Oversampled: 9912
# Num in Oversampled: 9919
# Num in Oversampled: 9926
# Num in Oversampled: 9933
# Num in Oversampled: 9940
# Num in Oversampled: 9947
# Num in Oversampled: 9954
# Num in Oversampled: 9961
# Num in Oversampled: 9968
# Num in Oversampled: 9975
# Num in Oversampled: 9982
# Num in Oversampled: 9989
# Num in Oversampled: 9996
# Num in Oversampled: 10003
# Num in Oversampled: 10010
# Num in Oversampled: 10017
# Num in Oversampled: 10024
# Num in Oversampled: 10031
# Num in Oversampled: 10038
# Num in Oversampled: 10045
# Num in Oversampled: 10052
# Num in Oversampled: 10059
# Num in Oversampled: 10066
# Num in Oversampled: 10073
# Num in Oversampled: 10080
# Num in Oversampled: 10087
# Num in Oversampled: 10094
# Num in Oversampled: 10101
# Num in Oversampled: 10108
# Num in Oversampled: 10115
# Num in Oversampled: 10122
# Num in Oversampled: 10129
# Num in Oversampled: 10136
# Num in Oversampled: 10143
# Num in Oversampled: 10150
# Num in Oversampled: 10157
# Num in Oversampled: 10164
# Num in Oversampled: 10171
# Num in Oversampled: 10178
# Num in Oversampled: 10185
# Num in Oversampled: 10192
# Num in Oversampled: 10199
# Num in Oversampled: 10206
# Num in Oversampled: 10213
# Num in Oversampled: 10220
# Num in Oversampled: 10227
# Num in Oversampled: 10234
# Num in Oversampled: 10241
# Num in Oversampled: 10248
# Num in Oversampled: 10255
# Num in Oversampled: 10262
# Num in Oversampled: 10269
# Num in Oversampled: 10276
# Num in Oversampled: 10283
# Num in Oversampled: 10290
# Num in Oversampled: 10297
# Num in Oversampled: 10304
# Num in Oversampled: 10311
# Num in Oversampled: 10318
# Num in Oversampled: 10325
# Num in Oversampled: 10332
# Num in Oversampled: 10339
# Num in Oversampled: 10346
# Num in Oversampled: 10353
# Num in Oversampled: 10360
# Num in Oversampled: 10367
# Num in Oversampled: 10374
# Num in Oversampled: 10381
# Num in Oversampled: 10388
# Num in Oversampled: 10395
# Num in Oversampled: 10402
# Num in Oversampled: 10409
# Num in Oversampled: 10416
# Num in Oversampled: 10423
# Num in Oversampled: 10430
# Num in Oversampled: 10437
# Num in Oversampled: 10444
# Num in Oversampled: 10451
# Num in Oversampled: 10458
# Num in Oversampled: 10465
# Num in Oversampled: 10472
# Num in Oversampled: 10479
# Num in Oversampled: 10486
# Num in Oversampled: 10493
# Num in Oversampled: 10500
# Num in Oversampled: 10507
# Num in Oversampled: 10514
# Num in Oversampled: 10521
# Num in Oversampled: 10528
# Num in Oversampled: 10535
# Num in Oversampled: 10542
# Num in Oversampled: 10549
# Num in Oversampled: 10556
# Num in Oversampled: 10563
# Num in Oversampled: 10570
# Num in Oversampled: 10577
# Num in Oversampled: 10584
# Num in Oversampled: 10591
# Num in Oversampled: 10598
# Num in Oversampled: 10605
# Num in Oversampled: 10612
# Num in Oversampled: 10619
# Num in Oversampled: 10626
# Num in Oversampled: 10633
# Num in Oversampled: 10640
# Num in Oversampled: 10647
# Num in Oversampled: 10654
# Num in Oversampled: 10661
# Num in Oversampled: 10668
# Num in Oversampled: 10675
# Num in Oversampled: 10682
# Num in Oversampled: 10689
# Num in Oversampled: 10696
# Num in Oversampled: 10703
# Num in Oversampled: 10710
# Num in Oversampled: 10717
# Num in Oversampled: 10724
# Num in Oversampled: 10731
# Num in Oversampled: 10738
# Num in Oversampled: 10745
# Num in Oversampled: 10752
# Num in Oversampled: 10759
# Num in Oversampled: 10766
# Num in Oversampled: 10773
# Num in Oversampled: 10780
# Num in Oversampled: 10787
# Num in Oversampled: 10794
# Num in Oversampled: 10801
# Num in Oversampled: 10808
# Num in Oversampled: 10815
# Num in Oversampled: 10822
# Num in Oversampled: 10829
# Num in Oversampled: 10836
# Num in Oversampled: 10843
# Num in Oversampled: 10850
# Num in Oversampled: 10857
# Num in Oversampled: 10864
# Num in Oversampled: 10871
# Num in Oversampled: 10878
# Num in Oversampled: 10885
# Num in Oversampled: 10892
# Num in Oversampled: 10899
# Num in Oversampled: 10906
# Num in Oversampled: 10913
# Num in Oversampled: 10920
# Num in Oversampled: 10927
# Num in Oversampled: 10934
# Num in Oversampled: 10941
# Num in Oversampled: 10948
# Num in Oversampled: 10955
# Num in Oversampled: 10962
# Num in Oversampled: 10969
# Num in Oversampled: 10976
# Num in Oversampled: 10983
# Num in Oversampled: 10990
# Num in Oversampled: 10997
# Num in Oversampled: 11004
# Num in Oversampled: 11011
# Num in Oversampled: 11018
# Num in Oversampled: 11025
# Num in Oversampled: 11032
# Num in Oversampled: 11039
# Num in Oversampled: 11046
# Num in Oversampled: 11053
# Num in Oversampled: 11060
# Num in Oversampled: 11067
# Num in Oversampled: 11074
# Num in Oversampled: 11081
# Num in Oversampled: 11088
# Num in Oversampled: 11095
# Num in Oversampled: 11102
# Num in Oversampled: 11109
# Num in Oversampled: 11116
# Num in Oversampled: 11123
# Num in Oversampled: 11130
# Num in Oversampled: 11137
# Num in Oversampled: 11144
# Num in Oversampled: 11151
# Num in Oversampled: 11158
# Num in Oversampled: 11165
# Num in Oversampled: 11172
# Num in Oversampled: 11179
# Num in Oversampled: 11186
# Num in Oversampled: 11193
# Num in Oversampled: 11200
# Num in Oversampled: 11207
# Num in Oversampled: 11214
# Num in Oversampled: 11221
# Num in Oversampled: 11228
# Num in Oversampled: 11235
# Num in Oversampled: 11242
# Num in Oversampled: 11249
# Num in Oversampled: 11256
# Num in Oversampled: 11263
# Num in Oversampled: 11270
# Num in Oversampled: 11277
# Num in Oversampled: 11284
# Num in Oversampled: 11291
# Num in Oversampled: 11298
# Num in Oversampled: 11305
# Num in Oversampled: 11312
# Num in Oversampled: 11319
# Num in Oversampled: 11326
# Num in Oversampled: 11333
# Num in Oversampled: 11340
# Num in Oversampled: 11347
# Num in Oversampled: 11354
# Num in Oversampled: 11361
# Num in Oversampled: 11368
# Num in Oversampled: 11375
# Num in Oversampled: 11382
# Num in Oversampled: 11389
# Num in Oversampled: 11396
# Num in Oversampled: 11403
# Num in Oversampled: 11410
# Num in Oversampled: 11417
# Num in Oversampled: 11424
# Num in Oversampled: 11431
# Num in Oversampled: 11438
# Num in Oversampled: 11445
# Num in Oversampled: 11452
# Num in Oversampled: 11459
# Num in Oversampled: 11466
# Num in Oversampled: 11473
# Num in Oversampled: 11480
# Num in Oversampled: 11487
# Num in Oversampled: 11494
# Num in Oversampled: 11501
# Num in Oversampled: 11508
# Num in Oversampled: 11515
# Num in Oversampled: 11522
# Num in Oversampled: 11529
# Num in Oversampled: 11536
# Num in Oversampled: 11543
# Num in Oversampled: 11550
# Num in Oversampled: 11557
# Num in Oversampled: 11564
# Num in Oversampled: 11571
# Num in Oversampled: 11578
# Num in Oversampled: 11585
# Num in Oversampled: 11592
# Num in Oversampled: 11599
# Num in Oversampled: 11606
# Num in Oversampled: 11613
# Num in Oversampled: 11620
# Num in Oversampled: 11627
# Num in Oversampled: 11634
# Num in Oversampled: 11641
# Num in Oversampled: 11648
# Num in Oversampled: 11655
# Num in Oversampled: 11662
# Num in Oversampled: 11669
# Num in Oversampled: 11676
# Num in Oversampled: 11683
# Num in Oversampled: 11690
# Num in Oversampled: 11697
# Num in Oversampled: 11704
# Num in Oversampled: 11711
# Num in Oversampled: 11718
# Num in Oversampled: 11725
# Num in Oversampled: 11732
# Num in Oversampled: 11739
# Num in Oversampled: 11746
# Num in Oversampled: 11753
# Num in Oversampled: 11760
# Num in Oversampled: 11767
# Num in Oversampled: 11774
# Num in Oversampled: 11781
# Num in Oversampled: 11788
# Num in Oversampled: 11795
# Num in Oversampled: 11802
# Num in Oversampled: 11809
# Num in Oversampled: 11816
# Num in Oversampled: 11823
# Num in Oversampled: 11830
# Num in Oversampled: 11837
# Num in Oversampled: 11844
# Num in Oversampled: 11851
# Num in Oversampled: 11858
# Num in Oversampled: 11865
# Num in Oversampled: 11872
# Num in Oversampled: 11879
# Num in Oversampled: 11886
# Num in Oversampled: 11893
# Num in Oversampled: 11900
# Num in Oversampled: 11907
# Num in Oversampled: 11914
# Num in Oversampled: 11921
# Num in Oversampled: 11928
# Num in Oversampled: 11935
# Num in Oversampled: 11942
# Num in Oversampled: 11949
# Num in Oversampled: 11956
# Num in Oversampled: 11963
# Num in Oversampled: 11970
# Num in Oversampled: 11977
# Num in Oversampled: 11984
# Num in Oversampled: 11991
# Num in Oversampled: 11998
# Num in Oversampled: 12005
# Num in Oversampled: 12012
# Num in Oversampled: 12019
# Num in Oversampled: 12026
# Num in Oversampled: 12033
# Num in Oversampled: 12040
# Num in Oversampled: 12047
# Num in Oversampled: 12054
# Num in Oversampled: 12061
# Num in Oversampled: 12068
# Num in Oversampled: 12075
# Num in Oversampled: 12082
# Num in Oversampled: 12089
# Num in Oversampled: 12096
# Num in Oversampled: 12103
# Num in Oversampled: 12110
# Num in Oversampled: 12117
# Num in Oversampled: 12124
# Num in Oversampled: 12131
# Num in Oversampled: 12138
# Num in Oversampled: 12145
# Num in Oversampled: 12152
# Num in Oversampled: 12159
# Num in Oversampled: 12166
# Num in Oversampled: 12173
# Num in Oversampled: 12180
# Num in Oversampled: 12187
# Num in Oversampled: 12194
# Num in Oversampled: 12201
# Num in Oversampled: 12208
# Num in Oversampled: 12215
# Num in Oversampled: 12222
# Num in Oversampled: 12229
# Num in Oversampled: 12236
# Num in Oversampled: 12243
# Num in Oversampled: 12250
# Num in Oversampled: 12257
# Num in Oversampled: 12264
# Num in Oversampled: 12271
# Num in Oversampled: 12278
# Num in Oversampled: 12285
# Num in Oversampled: 12292
# Num in Oversampled: 12299
# Num in Oversampled: 12306
# Num in Oversampled: 12313
# Num in Oversampled: 12320
# Num in Oversampled: 12327
# Num in Oversampled: 12334
# Num in Oversampled: 12341
# Num in Oversampled: 12348
# Num in Oversampled: 12355
# Num in Oversampled: 12362
# Num in Oversampled: 12369
# Num in Oversampled: 12376
# Num in Oversampled: 12383
# Num in Oversampled: 12390
# Num in Oversampled: 12397
# Num in Oversampled: 12404
# Num in Oversampled: 12411
# Num in Oversampled: 12418
# Num in Oversampled: 12425
# Num in Oversampled: 12432
# Num in Oversampled: 12439
# Num in Oversampled: 12446
# Num in Oversampled: 12453
# Num in Oversampled: 12460
# Num in Oversampled: 12467
# Num in Oversampled: 12474
# Num in Oversampled: 12481
# Num in Oversampled: 12488
# Num in Oversampled: 12495
# Num in Oversampled: 12502
# Num in Oversampled: 12509
# Num in Oversampled: 12516
# Num in Oversampled: 12523
# Num in Oversampled: 12530
# Num in Oversampled: 12537
# Num in Oversampled: 12544
# Num in Oversampled: 12551
# Num in Oversampled: 12558
# Num in Oversampled: 12565
# Num in Oversampled: 12572
# Num in Oversampled: 12579
# Num in Oversampled: 12586
# Num in Oversampled: 12593
# Num in Oversampled: 12600
# Num in Oversampled: 12607
# Num in Oversampled: 12614
# Num in Oversampled: 12621
# Num in Oversampled: 12628
# Num in Oversampled: 12635
# Num in Oversampled: 12642
# Num in Oversampled: 12649
# Num in Oversampled: 12656
# Num in Oversampled: 12663
# Num in Oversampled: 12670
# Num in Oversampled: 12677
# Num in Oversampled: 12684
# Num in Oversampled: 12691
# Num in Oversampled: 12698
# Num in Oversampled: 12705
# Num in Oversampled: 12712
# Num in Oversampled: 12719
# Num in Oversampled: 12726
# Num in Oversampled: 12733
# Num in Oversampled: 12740
# Num in Oversampled: 12747
# Num in Oversampled: 12754
# Num in Oversampled: 12761
# Num in Oversampled: 12768
# Num in Oversampled: 12775
# Num in Oversampled: 12782
# Num in Oversampled: 12789
# Num in Oversampled: 12796
# Num in Oversampled: 12803
# Num in Oversampled: 12810
# Num in Oversampled: 12817
# Num in Oversampled: 12824
# Num in Oversampled: 12831
# Num in Oversampled: 12838
# Num in Oversampled: 12845
# Num in Oversampled: 12852
# Num in Oversampled: 12859
# Num in Oversampled: 12866
# Num in Oversampled: 12873
# Num in Oversampled: 12880
# Num in Oversampled: 12887
# Num in Oversampled: 12894
# Num in Oversampled: 12901
# Num in Oversampled: 12908
# Num in Oversampled: 12915
# Num in Oversampled: 12922
# Num in Oversampled: 12929
# Num in Oversampled: 12936
# Num in Oversampled: 12943
# Num in Oversampled: 12950
# Num in Oversampled: 12957
# Num in Oversampled: 12964
# Num in Oversampled: 12971
# Num in Oversampled: 12978
# Num in Oversampled: 12985
# Num in Oversampled: 12992
# Num in Oversampled: 12999
# Num in Oversampled: 13006
# Num in Oversampled: 13013
# Num in Oversampled: 13020
# Num in Oversampled: 13027
# Num in Oversampled: 13034
# Num in Oversampled: 13041
# Num in Oversampled: 13048
# Num in Oversampled: 13055
# Num in Oversampled: 13062
# Num in Oversampled: 13069
# Num in Oversampled: 13076
# Num in Oversampled: 13083
# Num in Oversampled: 13090
# Num in Oversampled: 13097
# Num in Oversampled: 13104
# Num in Oversampled: 13111
# Num in Oversampled: 13118
# Num in Oversampled: 13125
# Num in Oversampled: 13132
# Num in Oversampled: 13139
# Num in Oversampled: 13146
# Num in Oversampled: 13153
# Num in Oversampled: 13160
# Num in Oversampled: 13167
# Num in Oversampled: 13174
# Num in Oversampled: 13181
# Num in Oversampled: 13188
# Num in Oversampled: 13195
# Num in Oversampled: 13202
# Num in Oversampled: 13209
# Num in Oversampled: 13216
# Num in Oversampled: 13223
# Num in Oversampled: 13230
# Num in Oversampled: 13237
# Num in Oversampled: 13244
# Num in Oversampled: 13251
# Num in Oversampled: 13258
# Num in Oversampled: 13265
# Num in Oversampled: 13272
# Num in Oversampled: 13279
# Num in Oversampled: 13286
# Num in Oversampled: 13293
# Num in Oversampled: 13300
# Num in Oversampled: 13307
# Num in Oversampled: 13314
# Num in Oversampled: 13321
# Num in Oversampled: 13328
# Num in Oversampled: 13335
# Num in Oversampled: 13342
# Num in Oversampled: 13349
# Num in Oversampled: 13356
# Num in Oversampled: 13363
# Num in Oversampled: 13370
# Num in Oversampled: 13377
# Num in Oversampled: 13384
# Num in Oversampled: 13391
# Num in Oversampled: 13398
# Num in Oversampled: 13405
# Num in Oversampled: 13412
# Num in Oversampled: 13419
# Num in Oversampled: 13426
# Num in Oversampled: 13433
# Num in Oversampled: 13440
# Num in Oversampled: 13447
# Num in Oversampled: 13454
# Num in Oversampled: 13461
# Num in Oversampled: 13468
# Num in Oversampled: 13475
# Num in Oversampled: 13482
# Num in Oversampled: 13489
# Num in Oversampled: 13496
# Num in Oversampled: 13503
# Num in Oversampled: 13510
# Num in Oversampled: 13517
# Num in Oversampled: 13524
# Num in Oversampled: 13531
# Num in Oversampled: 13538
# Num in Oversampled: 13545
# Num in Oversampled: 13552
# Num in Oversampled: 13559
# Num in Oversampled: 13566
# Num in Oversampled: 13573
# Num in Oversampled: 13580
# Num in Oversampled: 13587
# Num in Oversampled: 13594
# Num in Oversampled: 13601
# Num in Oversampled: 13608
# Num in Oversampled: 13615
# Num in Oversampled: 13622
# Num in Oversampled: 13629
# Num in Oversampled: 13636
# Num in Oversampled: 13643
# Num in Oversampled: 13650
# Num in Oversampled: 13657
# Num in Oversampled: 13664
# Num in Oversampled: 13671
# Num in Oversampled: 13678
# Num in Oversampled: 13685
# Num in Oversampled: 13692
# Num in Oversampled: 13699
# Num in Oversampled: 13706
# Num in Oversampled: 13713
# Num in Oversampled: 13720
# Num in Oversampled: 13727
# Num in Oversampled: 13734
# Num in Oversampled: 13741
# Num in Oversampled: 13748
# Num in Oversampled: 13755
# Num in Oversampled: 13762
# Num in Oversampled: 13769
# Num in Oversampled: 13776
# Num in Oversampled: 13783
# Num in Oversampled: 13790
# Num in Oversampled: 13797
# Num in Oversampled: 13804
# Num in Oversampled: 13811
# Num in Oversampled: 13818
# Num in Oversampled: 13825
# Num in Oversampled: 13832
# Num in Oversampled: 13839
# Num in Oversampled: 13846
# Num in Oversampled: 13853
# Num in Oversampled: 13860
# Num in Oversampled: 13867
# Num in Oversampled: 13874
# Num in Oversampled: 13881
# Num in Oversampled: 13888
# Num in Oversampled: 13895
# Num in Oversampled: 13902
# Num in Oversampled: 13909
# Num in Oversampled: 13916
# Num in Oversampled: 13923
# Num in Oversampled: 13930
# Num in Oversampled: 13937
# Num in Oversampled: 13944
# Num in Oversampled: 13951
# Num in Oversampled: 13958
# Num in Oversampled: 13965
# Num in Oversampled: 13972
# Num in Oversampled: 13979
# Num in Oversampled: 13986
# Num in Oversampled: 13993
# Num in Oversampled: 14000
# 1000:1
#               precision    recall  f1-score   support
#
#          red       0.00      0.67      0.01         3
#         blue       1.00      0.86      0.93      3000
#
#     accuracy                           0.86      3003
#    macro avg       0.50      0.76      0.47      3003
# weighted avg       1.00      0.86      0.92      3003
#
# For dataset 1, numClass0=75, imbalance=93.0
# Num in Oversampled: 7070
# Num in Oversampled: 7145
# Num in Oversampled: 7220
# Num in Oversampled: 7295
# Num in Oversampled: 7370
# Num in Oversampled: 7445
# Num in Oversampled: 7520
# Num in Oversampled: 7595
# Num in Oversampled: 7670
# Num in Oversampled: 7745
# Num in Oversampled: 7820
# Num in Oversampled: 7895
# Num in Oversampled: 7970
# Num in Oversampled: 8045
# Num in Oversampled: 8120
# Num in Oversampled: 8195
# Num in Oversampled: 8270
# Num in Oversampled: 8345
# Num in Oversampled: 8420
# Num in Oversampled: 8495
# Num in Oversampled: 8570
# Num in Oversampled: 8645
# Num in Oversampled: 8720
# Num in Oversampled: 8795
# Num in Oversampled: 8870
# Num in Oversampled: 8945
# Num in Oversampled: 9020
# Num in Oversampled: 9095
# Num in Oversampled: 9170
# Num in Oversampled: 9245
# Num in Oversampled: 9320
# Num in Oversampled: 9395
# Num in Oversampled: 9470
# Num in Oversampled: 9545
# Num in Oversampled: 9620
# Num in Oversampled: 9695
# Num in Oversampled: 9770
# Num in Oversampled: 9845
# Num in Oversampled: 9920
# Num in Oversampled: 9995
# Num in Oversampled: 10070
# Num in Oversampled: 10145
# Num in Oversampled: 10220
# Num in Oversampled: 10295
# Num in Oversampled: 10370
# Num in Oversampled: 10445
# Num in Oversampled: 10520
# Num in Oversampled: 10595
# Num in Oversampled: 10670
# Num in Oversampled: 10745
# Num in Oversampled: 10820
# Num in Oversampled: 10895
# Num in Oversampled: 10970
# Num in Oversampled: 11045
# Num in Oversampled: 11120
# Num in Oversampled: 11195
# Num in Oversampled: 11270
# Num in Oversampled: 11345
# Num in Oversampled: 11420
# Num in Oversampled: 11495
# Num in Oversampled: 11570
# Num in Oversampled: 11645
# Num in Oversampled: 11720
# Num in Oversampled: 11795
# Num in Oversampled: 11870
# Num in Oversampled: 11945
# Num in Oversampled: 12020
# Num in Oversampled: 12095
# Num in Oversampled: 12170
# Num in Oversampled: 12245
# Num in Oversampled: 12320
# Num in Oversampled: 12395
# Num in Oversampled: 12470
# Num in Oversampled: 12545
# Num in Oversampled: 12620
# Num in Oversampled: 12695
# Num in Oversampled: 12770
# Num in Oversampled: 12845
# Num in Oversampled: 12920
# Num in Oversampled: 12995
# Num in Oversampled: 13070
# Num in Oversampled: 13145
# Num in Oversampled: 13220
# Num in Oversampled: 13295
# Num in Oversampled: 13370
# Num in Oversampled: 13445
# Num in Oversampled: 13520
# Num in Oversampled: 13595
# Num in Oversampled: 13670
# Num in Oversampled: 13745
# Num in Oversampled: 13820
# Num in Oversampled: 13895
# Num in Oversampled: 13970
# 100:1
#               precision    recall  f1-score   support
#
#          red       0.05      0.84      0.09        25
#         blue       1.00      0.86      0.93      3005
#
#     accuracy                           0.86      3030
#    macro avg       0.52      0.85      0.51      3030
# weighted avg       0.99      0.86      0.92      3030
#
# For dataset 2, numClass0=686, imbalance=10.0
# Num in Oversampled: 7700
# Num in Oversampled: 8386
# Num in Oversampled: 9072
# Num in Oversampled: 9758
# Num in Oversampled: 10444
# Num in Oversampled: 11130
# Num in Oversampled: 11816
# Num in Oversampled: 12502
# Num in Oversampled: 13188
# Num in Oversampled: 13874
# 10:1
#               precision    recall  f1-score   support
#
#          red       0.43      0.90      0.58       314
#         blue       0.99      0.87      0.93      2986
#
#     accuracy                           0.88      3300
#    macro avg       0.71      0.89      0.75      3300
# weighted avg       0.93      0.88      0.89      3300
#
# For dataset 3, numClass0=6975, imbalance=1.0
# Num in Oversampled: 14000
# 1:1
#               precision    recall  f1-score   support
#
#          red       0.88      0.87      0.87      3025
#         blue       0.87      0.88      0.87      2975
#
#     accuracy                           0.87      6000
#    macro avg       0.87      0.87      0.87      6000
# weighted avg       0.87      0.87      0.87      6000

# %% [markdown]
# ## Discussion 2
# - Which was more successful, under- or over-sampling?
# - What other ways could you combat class imbalance?
# - Which performance metrics would you use?
#
# ---
#
# ### Bonus: Synthetic Minority Oversampling Technique (SMOTE)
#
# SMOTE-variants

# %%
# !pip install smote-variants
# Out:
# Collecting smote-variants
#   Downloading smote_variants-0.4.0-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 7.9 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from smote-variants) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from smote-variants) (1.0.1)
# Collecting minisom
#   Downloading MiniSom-2.2.9.tar.gz (8.1 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from smote-variants) (1.1.5)
# Collecting statistics
#   Downloading statistics-1.0.3.5.tar.gz (8.3 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from smote-variants) (1.1.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from smote-variants) (2.7.0)
# Requirement already satisfied: mkl in /usr/local/lib/python3.7/dist-packages (from smote-variants) (2019.0)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from smote-variants) (1.19.5)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from smote-variants) (2.7.0)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.7/dist-packages (from mkl->smote-variants) (2021.4.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->smote-variants) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->smote-variants) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->smote-variants) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->smote-variants) (3.0.0)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.7/dist-packages (from statistics->smote-variants) (0.17.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (0.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (3.1.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (2.7.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (0.37.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (3.17.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (0.22.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (1.42.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (12.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (3.10.0.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (1.13.3)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote-variants) (1.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->smote-variants) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow->smote-variants) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->smote-variants) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->smote-variants) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->smote-variants) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->smote-variants) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow->smote-variants) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow->smote-variants) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow->smote-variants) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->smote-variants) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->smote-variants) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->smote-variants) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->smote-variants) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->smote-variants) (3.1.1)
# Building wheels for collected packages: minisom, statistics
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.2.9-py3-none-any.whl size=8594 sha256=c6d5f87e8c6238d8abdbe709d8a62a57397f608d343928ab1329eaa757a87630
#   Stored in directory: /root/.cache/pip/wheels/3d/a1/10/f50b6f4865652eac239a2700de411c3078c27e1318320e494c
#   Building wheel for statistics (setup.py) ... done
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7452 sha256=0507890015b019e2441418c1dd9aba6974e5ca965c523df218900f21082825e8
#   Stored in directory: /root/.cache/pip/wheels/37/09/e1/49ee45c0ce248a6e9c986aae82d32bbcba09c9f3b9d0c3406a
# Successfully built minisom statistics
# Installing collected packages: statistics, minisom, smote-variants
# Successfully installed minisom-2.2.9 smote-variants-0.4.0 statistics-1.0.3.5

# %%
import matplotlib.pyplot as plt
import smote_variants as sv
from sklearn.datasets import load_wine

wine_bunch = load_wine()

X, y= wine_bunch['data'], wine_bunch['target']

oversampler= sv.MulticlassOversampling(sv.distance_SMOTE())

# X_samp and y_samp contain the oversampled dataset
X_samp, y_samp= oversampler.sample(X, y)
plt.scatter(X[:,0], X[:,1], alpha=0.3, c=y, cmap='viridis')
plt.title(f'num total: {len(X)}')
# Out:
# 2021-11-20 22:25:23,702:INFO:MulticlassOversampling: Running multiclass oversampling with strategy eq_1_vs_many_successive
# 2021-11-20 22:25:23,708:INFO:MulticlassOversampling: Sampling minority class with label: 0
# 2021-11-20 22:25:23,711:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': None}")
# 2021-11-20 22:25:23,720:INFO:MulticlassOversampling: Sampling minority class with label: 2
# 2021-11-20 22:25:23,723:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 0.24468085106382978, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': None}")
# Text(0.5, 1.0, 'num total: 178')

# %%
plt.scatter(X_samp[:,0], X_samp[:,1], alpha=1, c=y_samp, cmap='viridis')
plt.title(f'num total: {len(X)}')
# Out:
# Text(0.5, 1.0, 'num total: 178')

# %% [markdown]
# ### Excitingly: There are a tremendous number of techniques available!
#
# The implemented techniques: [SMOTE] , [SMOTE_TomekLinks] , [SMOTE_ENN] , [Borderline_SMOTE1] , [Borderline_SMOTE2] , [ADASYN] , [AHC] , [LLE_SMOTE] , [distance_SMOTE] , [SMMO] , [polynom_fit_SMOTE] , [Stefanowski] , [ADOMS] , [Safe_Level_SMOTE] , [MSMOTE] , [DE_oversampling] , [SMOBD] , [SUNDO] , [MSYN] , [SVM_balance] , [TRIM_SMOTE] , [SMOTE_RSB] , [ProWSyn] , [SL_graph_SMOTE] , [NRSBoundary_SMOTE] , [LVQ_SMOTE] , [SOI_CJ] , [ROSE] , [SMOTE_OUT] , [SMOTE_Cosine] , [Selected_SMOTE] , [LN_SMOTE] , [MWMOTE] , [PDFOS] , [IPADE_ID] , [RWO_sampling] , [NEATER] , [DEAGO] , [Gazzah] , [MCT] , [ADG] , [SMOTE_IPF] , [KernelADASYN] , [MOT2LD] , [V_SYNTH] , [OUPS] , [SMOTE_D] , [SMOTE_PSO] , [CURE_SMOTE] , [SOMO] , [ISOMAP_Hybrid] , [CE_SMOTE] , [Edge_Det_SMOTE] , [CBSO] , [E_SMOTE] , [DBSMOTE] , [ASMOBD] , [Assembled_SMOTE] , [SDSMOTE] , [DSMOTE] , [G_SMOTE] , [NT_SMOTE] , [Lee] , [SPY] , [SMOTE_PSOBAT] , [MDO] , [Random_SMOTE] , [ISMOTE] , [VIS_RST] , [GASMOTE] , [A_SUWO] , [SMOTE_FRST_2T] , [AND_SMOTE] , [NRAS] , [AMSCO] , [SSO] , [NDO_sampling] , [DSRBF] , [Gaussian_SMOTE] , [kmeans_SMOTE] , [Supervised_SMOTE] , [SN_SMOTE] , [CCR] , [ANS] , [cluster_SMOTE]
#
#
# ---
#
# ## Part II: k-Means Implementation in Python

# %%
# Import necessary libraries
from copy import deepcopy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
from IPython.display import clear_output

# Set three centers, the model should predict similar results
center_1 = np.array([1,1])
center_2 = np.array([5,5])
center_3 = np.array([8,1])

# Generate random data and center it to the three centers
data_1 = np.random.randn(200, 2) + center_1
data_2 = np.random.randn(200,2) + center_2
data_3 = np.random.randn(200,2) + center_3

data = np.concatenate((data_1, data_2, data_3), axis = 0)

plt.scatter(data[:,0], data[:,1], s=7)

# %%
# Number of clusters
k = 3
# Number of training data
n = data.shape[0]
# Number of features in the data
c = data.shape[1]

# Generate random centers, here we use sigma and mean to ensure it represent the whole data
mean = np.mean(data, axis = 0)
std = np.std(data, axis = 0)
centers = np.random.randn(k,c)*std + mean

# Plot the data and the centers generated as random
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(centers[:,0], centers[:,1], marker='*', c='g', s=150)

# %%
centers_old = np.zeros(centers.shape) # to store old centers
centers_new = deepcopy(centers) # Store new centers

data.shape
clusters = np.zeros(n)
distances = np.zeros((n,k))

error = np.linalg.norm(centers_new - centers_old)

# When, after an update, the estimate of that center stays the same, exit loop
while error != 0:
    # Measure the distance to every center
    for i in range(k):
        distances[:,i] = np.linalg.norm(data - centers[i], axis=1)
    # Assign all training data to closest center
    clusters = np.argmin(distances, axis = 1)
    
    centers_old = deepcopy(centers_new)
    # Calculate mean for every cluster and update the center
    for i in range(k):
        centers_new[i] = np.mean(data[clusters == i], axis=0)
        clear_output
        plt.scatter(data[:,0], data[:,1], s=7)
        plt.scatter(centers_new[:,0], centers_new[:,1], marker='*', c='g', s=150)
    error = np.linalg.norm(centers_new - centers_old)
centers_new
# Out:
# array([[ 6.52018672,  2.93135436],
#        [ 2.0763682 , -1.14428961],
#        [ 0.95885222,  1.23329795]])

# %%
# Plot the data and the centers generated as random
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(centers_new[:,0], centers_new[:,1], marker='*', c='g', s=150)

# %% [markdown]
# #FIN
