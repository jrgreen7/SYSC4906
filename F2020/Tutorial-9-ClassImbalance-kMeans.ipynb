# %% [markdown]
# # Tutorial 9 - Class Imbalance & k-Means
#
# **Semester:** Fall 2020
#
# **Adapted by:** [Kevin Dick](https://kevindick.ai/)
#
# **Part I adapted from:** [Scikit-Learn's Plot Classifier Performance](https://scikit-learn.org/0.15/auto_examples/plot_classifier_comparison.html).
#
# **Part II adapted from:** Andrew Yue Xie's [K-Means Clustering Implementation in Python](https://www.kaggle.com/andyxie/k-means-clustering-implementation-in-python)
#
# ---
#
#
#
# ## 1. Introduction
# In this notebook, we will explore four different classifiers and how they perform on artificial datasets with linear and nonlinear class distributions, as the class imbalance changes from 1:1 to 1:100. We are most interested in how the decision boundaries change between various classifiers. We will then explore under-sampling as a way to solve the issue.
#
# <i>Note that this Notebook is based on https://scikit-learn.org/0.15/auto_examples/plot_classifier_comparison.html</i>
#
# The classifiers we will be looking at are:
# - Logistic regression
# - Decision tree
# - linear SVM
# - SVM with a nonlinear kernel
# - K-Nearest-Neighbour <i>(yes, neighbour has a 'u'...)</i>
#
# Scikit-learn has a powerful toolboxes for building classifiers, creating artificial data, and visualizing decision boundaries. The toolboxes can be seen in the import calls below.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
import seaborn as sb

# %% [markdown]
# We import these packages, but as usual we will also need numpy and matplotlib. Let's import those packages now.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## 2. The Data
#
# Generate datasets with 1:1 class imbalance. Increase this to 1:10 and 1:100.

# %%
# Create 4 datasets of varying class imbalance:

# 1) Dataset where classes are distributed in moons
allX, ally = make_moons(noise=0.2, random_state=1, n_samples=20000)
allX_1 = allX[ally==1]
allX_0 = allX[ally==0]
ally_1 = ally[ally==1]
ally_0 = ally[ally==0]

numClass0 = 10 #1000:1
X1000 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y1000 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

numClass0 = 100 #100:1
X100 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y100 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

numClass0 = 1000 #10:1
X10 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y10 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

numClass0 = 10000 #1:1
X1 = np.concatenate((allX_1,allX_0[:numClass0,:]),axis=0) 
y1 = np.concatenate((ally_1, ally_0[:numClass0]),axis=0)

# Gather all four datasets
datasets = [(X1000,y1000),
            (X100,y100),
            (X10,y10),
            (X1,y1)]

dataset_names= ["1000:1", "100:1", "10:1", "1:1"]

## Visualize the datasets

#Plot 1000:1 data
plt.figure(figsize= (12,12))
plt.subplot(2, 2, 1)
plt.scatter(X1000[0:,0], X1000[0:,1], c=y1000)
plt.title(dataset_names[0])

#Plot Circles data
plt.subplot(2, 2, 2)
plt.scatter(X100[0:,0], X100[0:,1], c=y100)
plt.title(dataset_names[1])

#Plot Linearly separable
plt.subplot(2, 2, 3)
plt.scatter(X10[0:,0], X10[0:,1], c=y10)
plt.title(dataset_names[2])

#Plot Linearly separable
plt.subplot(2, 2, 4)
plt.scatter(X1[0:,0], X1[0:,1], c=y1)
plt.title(dataset_names[3]);  #(adding semi-colon suppresses output of text "Noisy Linearly Separable")

# %% [markdown]
# We've had a look at the data, now let's prepare our classifiers so that we can later evaluate how they perform on each dataset.

# %%
classifierNames = ["Logistic Regression", "Decision Tree", "Linear SVM", "RBF SVM","KNN"]

classifiers = [
    LogisticRegression(solver='lbfgs'), #Logistic regression
    DecisionTreeClassifier(max_depth=5), #Decision tree classifier with max_depth=5
    SVC(kernel="linear", C=0.025), #Linear SVM classifier
    SVC(kernel= 'rbf', gamma=2, C=1.0), # SVM with radial basis function kernel, gamma is kernel coefficient, C is penalty parameter for misclassified points
    KNeighborsClassifier(3)]

# %% [markdown]
# ## 3. Classifier Performance
#
# In this section, we will visualize the decision boundary for each classifier and compute the accuracy for each classifier on each dataset. We will follow the same training and testing protocol as in the CarsRegression notebook.

# %%
from sklearn.metrics import classification_report

h = .02  # Resolution in colored mesh visualizations
i= 1
figure = plt.figure(figsize=(27, 9))
j= 0


for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Set plot axis limits
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    
    # Prepare some nice visualizations
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    
    # Plot the datasets in first column
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i, title=dataset_names[j])
    j+= 1
    # Plot the training points 
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
    
    # Plot the testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6)
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1
    
    # Iterate over classifiers ('zip' iterates through two equal-length lists simultaneously)
    for name, clf in zip(classifierNames, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
        
        # Train and test our classifier
        clf.fit(X_train, y_train) # create classification model using training data
        score = clf.score(X_test, y_test) # evaluate classifier on the testing set

        # Plot the decision boundary. For that, we will assign a color to each point in the mesh [x_min, m_max]x[y_min, y_max].
        if hasattr(clf, "decision_function"):
            # flatten xx and yy to 1D arrays and get decision function, or decision boundary hyperplane
            Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()]) 
        else:
            # if no decision function available, use prediction probability as contrast for contour lines
            Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1] 

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

        # Plot the training points
        #ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
        
        # Plot the testing points (use alpha=0.6 to make them slightly transparent)
        ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright,
                   alpha=0.6)

        # Set axes limits
        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())

        # Add a title and overlay the prediction score onto the bottom-right corner of the plot
        ax.set_title(name)
        ax.text(xx.max() - .3, yy.min() + .3, ('%.3f' % score).lstrip('0'),
                size=15, horizontalalignment='right')
        i += 1

figure.subplots_adjust(left=.02, right=.98)
plt.show()

# %%
from sklearn.metrics import classification_report
j= 0

for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Look at Logistic Regression:
    name = classifierNames[0]
    clf = classifiers[0]

    # Train and test our classifier
    clf.fit(X_train, y_train) # create classification model using training data
    i += 1

    # Accuracy on the plot is not telling the whole story. Print classification report
    y_pred = clf.predict(X_test)
    target_names = ['red', 'blue']
    print(dataset_names[j])
    print(classification_report(y_test, y_pred, target_names=target_names))
    j+=1
# Out:
# 1000:1
#               precision    recall  f1-score   support
#
#          red       0.00      0.00      0.00         3
#         blue       1.00      1.00      1.00      3000
#
#     accuracy                           1.00      3003
#    macro avg       0.50      0.50      0.50      3003
# weighted avg       1.00      1.00      1.00      3003
#
# 100:1
#               precision    recall  f1-score   support
#
#          red       1.00      0.15      0.27        26
#         blue       0.99      1.00      1.00      3004
#
#     accuracy                           0.99      3030
#    macro avg       1.00      0.58      0.63      3030
# weighted avg       0.99      0.99      0.99      3030
#
# 10:1
#               precision    recall  f1-score   support
#
#          red       0.80      0.57      0.66       295
#         blue       0.96      0.99      0.97      3005
#
#     accuracy                           0.95      3300
#    macro avg       0.88      0.78      0.82      3300
# weighted avg       0.94      0.95      0.94      3300
#
# 1:1
#               precision    recall  f1-score   support
#
#          red       0.87      0.86      0.87      2997
#         blue       0.86      0.87      0.87      3003
#
#     accuracy                           0.87      6000
#    macro avg       0.87      0.87      0.87      6000
# weighted avg       0.87      0.87      0.87      6000
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# code modified from: https://scikit-learn.org/0.15/auto_examples/plot_classifier_comparison.html
#
# ## 4. Discussion
#
# - What did the full classification report show that the accuracy in the plots did not?
# - How would you address the class imbalance?
#
# ## 5. Try Subsampling of Majority (blue) Class to Achieve "Balanced Training Set"

# %%
# Try subsampling from the dominant class to achieve 1:1 balance in training only

from sklearn.metrics import classification_report
j= 0

for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Apply subsampling:
    X_train_1 = X_train[y_train==1]
    X_train_0 = X_train[y_train==0]
    y_train_1 = y_train[y_train==1]
    y_train_0 = y_train[y_train==0]
    numClass0 = len(X_train)-sum(y_train)
    imbalance = len(X_train_1)/len(X_train_0)
    print("For dataset {0:d}, numClass0={1:d}, imbalance={2:.1f}".format(j,numClass0,round(imbalance)))
    X_train_SS = np.concatenate((X_train_0,X_train_1[:numClass0,:]),axis=0) 
    y_train_SS = np.concatenate((y_train_0, y_train_1[:numClass0]),axis=0) 

    ### Really should shuffle the dataset since it is now organized by classID...
    assert len(X_train_SS) == len(y_train_SS)
    p = np.random.permutation(len(X_train_SS))
    X_train_SS =  X_train_SS[p]
    y_train_SS = y_train_SS[p]
    print(f'Num in Subsampled: {len(X_train_SS)}')

    # Look at Logistic Regression:
    name = classifierNames[0]
    clf = classifiers[0]

    # Train and test our classifier
    clf.fit(X_train_SS, y_train_SS) # create classification model using training data

    # Print classification report
    y_pred = clf.predict(X_test)
    target_names = ['red', 'blue']
    print(dataset_names[j])
    print(classification_report(y_test, y_pred, target_names=target_names))
    j+=1
# Out:
# For dataset 0, numClass0=7, imbalance=1000.0
# Num in Subsampled: 14
# 1000:1
#               precision    recall  f1-score   support
#
#          red       0.01      1.00      0.01         3
#         blue       1.00      0.87      0.93      3000
#
#     accuracy                           0.87      3003
#    macro avg       0.50      0.93      0.47      3003
# weighted avg       1.00      0.87      0.93      3003
#
# For dataset 1, numClass0=65, imbalance=108.0
# Num in Subsampled: 130
# 100:1
#               precision    recall  f1-score   support
#
#          red       0.06      0.89      0.11        35
#         blue       1.00      0.84      0.91      2995
#
#     accuracy                           0.84      3030
#    macro avg       0.53      0.86      0.51      3030
# weighted avg       0.99      0.84      0.90      3030
#
# For dataset 2, numClass0=680, imbalance=10.0
# Num in Subsampled: 1360
# 10:1
#               precision    recall  f1-score   support
#
#          red       0.42      0.88      0.57       320
#         blue       0.99      0.87      0.92      2980
#
#     accuracy                           0.87      3300
#    macro avg       0.70      0.88      0.75      3300
# weighted avg       0.93      0.87      0.89      3300
#
# For dataset 3, numClass0=6997, imbalance=1.0
# Num in Subsampled: 13994
# 1:1
#               precision    recall  f1-score   support
#
#          red       0.87      0.87      0.87      3003
#         blue       0.87      0.87      0.87      2997
#
#     accuracy                           0.87      6000
#    macro avg       0.87      0.87      0.87      6000
# weighted avg       0.87      0.87      0.87      6000

# %% [markdown]
# ##6. Try Over-sampling the Rare (red) Class to Achieve a "Balanced Training Set"

# %%
# Try over-sampling from the rare class (red) to achieve 1:1 balance in training only

from sklearn.metrics import classification_report
j= 0

for ds in datasets:
    
    # Preprocess dataset, split into training and test part
    X, y = ds # X is feature vectors, y is class labels
    X = StandardScaler().fit_transform(X) # Standardize features by removing the mean and scaling to unit variance
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3) # handy function
    
    # Apply subsampling:
    X_train_1 = X_train[y_train==1]
    X_train_0 = X_train[y_train==0]
    y_train_1 = y_train[y_train==1]
    y_train_0 = y_train[y_train==0]
    numClass0 = len(X_train)-sum(y_train)
    imbalance = len(X_train_1)/len(X_train_0)
    print("For dataset {0:d}, numClass0={1:d}, imbalance={2:.1f}".format(j,numClass0,round(imbalance)))

    # To over-sample, add 'imbalance' copies of class 0 data:
    X_train_OS = X_train_1 
    y_train_OS = y_train_1 
    for k in range(round(imbalance)):
      X_train_OS = np.concatenate((X_train_OS,X_train_0),axis=0) 
      y_train_OS = np.concatenate((y_train_OS,y_train_0),axis=0) 
      print(f'Num in Oversampled: {len(X_train_OS)}')

    ### Really should shuffle the dataset since it is now organized by classID...
    assert len(X_train_OS) == len(y_train_OS)
    p = np.random.permutation(len(X_train_OS))
    X_train_OS =  X_train_OS[p]
    y_train_OS = y_train_OS[p]

    # Look at Logistic Regression:
    name = classifierNames[0]
    clf = classifiers[0]

    # Train and test our classifier
    clf.fit(X_train_OS, y_train_OS) # create classification model using training data

    # Print classification report
    y_pred = clf.predict(X_test)
    target_names = ['red', 'blue']
    print(dataset_names[j])
    print(classification_report(y_test, y_pred, target_names=target_names))
    j+=1
# Out:
# For dataset 0, numClass0=8, imbalance=875.0
# Num in Oversampled: 7007
# Num in Oversampled: 7015
# Num in Oversampled: 7023
# Num in Oversampled: 7031
# Num in Oversampled: 7039
# Num in Oversampled: 7047
# Num in Oversampled: 7055
# Num in Oversampled: 7063
# Num in Oversampled: 7071
# Num in Oversampled: 7079
# Num in Oversampled: 7087
# Num in Oversampled: 7095
# Num in Oversampled: 7103
# Num in Oversampled: 7111
# Num in Oversampled: 7119
# Num in Oversampled: 7127
# Num in Oversampled: 7135
# Num in Oversampled: 7143
# Num in Oversampled: 7151
# Num in Oversampled: 7159
# Num in Oversampled: 7167
# Num in Oversampled: 7175
# Num in Oversampled: 7183
# Num in Oversampled: 7191
# Num in Oversampled: 7199
# Num in Oversampled: 7207
# Num in Oversampled: 7215
# Num in Oversampled: 7223
# Num in Oversampled: 7231
# Num in Oversampled: 7239
# Num in Oversampled: 7247
# Num in Oversampled: 7255
# Num in Oversampled: 7263
# Num in Oversampled: 7271
# Num in Oversampled: 7279
# Num in Oversampled: 7287
# Num in Oversampled: 7295
# Num in Oversampled: 7303
# Num in Oversampled: 7311
# Num in Oversampled: 7319
# Num in Oversampled: 7327
# Num in Oversampled: 7335
# Num in Oversampled: 7343
# Num in Oversampled: 7351
# Num in Oversampled: 7359
# Num in Oversampled: 7367
# Num in Oversampled: 7375
# Num in Oversampled: 7383
# Num in Oversampled: 7391
# Num in Oversampled: 7399
# Num in Oversampled: 7407
# Num in Oversampled: 7415
# Num in Oversampled: 7423
# Num in Oversampled: 7431
# Num in Oversampled: 7439
# Num in Oversampled: 7447
# Num in Oversampled: 7455
# Num in Oversampled: 7463
# Num in Oversampled: 7471
# Num in Oversampled: 7479
# Num in Oversampled: 7487
# Num in Oversampled: 7495
# Num in Oversampled: 7503
# Num in Oversampled: 7511
# Num in Oversampled: 7519
# Num in Oversampled: 7527
# Num in Oversampled: 7535
# Num in Oversampled: 7543
# Num in Oversampled: 7551
# Num in Oversampled: 7559
# Num in Oversampled: 7567
# Num in Oversampled: 7575
# Num in Oversampled: 7583
# Num in Oversampled: 7591
# Num in Oversampled: 7599
# Num in Oversampled: 7607
# Num in Oversampled: 7615
# Num in Oversampled: 7623
# Num in Oversampled: 7631
# Num in Oversampled: 7639
# Num in Oversampled: 7647
# Num in Oversampled: 7655
# Num in Oversampled: 7663
# Num in Oversampled: 7671
# Num in Oversampled: 7679
# Num in Oversampled: 7687
# Num in Oversampled: 7695
# Num in Oversampled: 7703
# Num in Oversampled: 7711
# Num in Oversampled: 7719
# Num in Oversampled: 7727
# Num in Oversampled: 7735
# Num in Oversampled: 7743
# Num in Oversampled: 7751
# Num in Oversampled: 7759
# Num in Oversampled: 7767
# Num in Oversampled: 7775
# Num in Oversampled: 7783
# Num in Oversampled: 7791
# Num in Oversampled: 7799
# Num in Oversampled: 7807
# Num in Oversampled: 7815
# Num in Oversampled: 7823
# Num in Oversampled: 7831
# Num in Oversampled: 7839
# Num in Oversampled: 7847
# Num in Oversampled: 7855
# Num in Oversampled: 7863
# Num in Oversampled: 7871
# Num in Oversampled: 7879
# Num in Oversampled: 7887
# Num in Oversampled: 7895
# Num in Oversampled: 7903
# Num in Oversampled: 7911
# Num in Oversampled: 7919
# Num in Oversampled: 7927
# Num in Oversampled: 7935
# Num in Oversampled: 7943
# Num in Oversampled: 7951
# Num in Oversampled: 7959
# Num in Oversampled: 7967
# Num in Oversampled: 7975
# Num in Oversampled: 7983
# Num in Oversampled: 7991
# Num in Oversampled: 7999
# Num in Oversampled: 8007
# Num in Oversampled: 8015
# Num in Oversampled: 8023
# Num in Oversampled: 8031
# Num in Oversampled: 8039
# Num in Oversampled: 8047
# Num in Oversampled: 8055
# Num in Oversampled: 8063
# Num in Oversampled: 8071
# Num in Oversampled: 8079
# Num in Oversampled: 8087
# Num in Oversampled: 8095
# Num in Oversampled: 8103
# Num in Oversampled: 8111
# Num in Oversampled: 8119
# Num in Oversampled: 8127
# Num in Oversampled: 8135
# Num in Oversampled: 8143
# Num in Oversampled: 8151
# Num in Oversampled: 8159
# Num in Oversampled: 8167
# Num in Oversampled: 8175
# Num in Oversampled: 8183
# Num in Oversampled: 8191
# Num in Oversampled: 8199
# Num in Oversampled: 8207
# Num in Oversampled: 8215
# Num in Oversampled: 8223
# Num in Oversampled: 8231
# Num in Oversampled: 8239
# Num in Oversampled: 8247
# Num in Oversampled: 8255
# Num in Oversampled: 8263
# Num in Oversampled: 8271
# Num in Oversampled: 8279
# Num in Oversampled: 8287
# Num in Oversampled: 8295
# Num in Oversampled: 8303
# Num in Oversampled: 8311
# Num in Oversampled: 8319
# Num in Oversampled: 8327
# Num in Oversampled: 8335
# Num in Oversampled: 8343
# Num in Oversampled: 8351
# Num in Oversampled: 8359
# Num in Oversampled: 8367
# Num in Oversampled: 8375
# Num in Oversampled: 8383
# Num in Oversampled: 8391
# Num in Oversampled: 8399
# Num in Oversampled: 8407
# Num in Oversampled: 8415
# Num in Oversampled: 8423
# Num in Oversampled: 8431
# Num in Oversampled: 8439
# Num in Oversampled: 8447
# Num in Oversampled: 8455
# Num in Oversampled: 8463
# Num in Oversampled: 8471
# Num in Oversampled: 8479
# Num in Oversampled: 8487
# Num in Oversampled: 8495
# Num in Oversampled: 8503
# Num in Oversampled: 8511
# Num in Oversampled: 8519
# Num in Oversampled: 8527
# Num in Oversampled: 8535
# Num in Oversampled: 8543
# Num in Oversampled: 8551
# Num in Oversampled: 8559
# Num in Oversampled: 8567
# Num in Oversampled: 8575
# Num in Oversampled: 8583
# Num in Oversampled: 8591
# Num in Oversampled: 8599
# Num in Oversampled: 8607
# Num in Oversampled: 8615
# Num in Oversampled: 8623
# Num in Oversampled: 8631
# Num in Oversampled: 8639
# Num in Oversampled: 8647
# Num in Oversampled: 8655
# Num in Oversampled: 8663
# Num in Oversampled: 8671
# Num in Oversampled: 8679
# Num in Oversampled: 8687
# Num in Oversampled: 8695
# Num in Oversampled: 8703
# Num in Oversampled: 8711
# Num in Oversampled: 8719
# Num in Oversampled: 8727
# Num in Oversampled: 8735
# Num in Oversampled: 8743
# Num in Oversampled: 8751
# Num in Oversampled: 8759
# Num in Oversampled: 8767
# Num in Oversampled: 8775
# Num in Oversampled: 8783
# Num in Oversampled: 8791
# Num in Oversampled: 8799
# Num in Oversampled: 8807
# Num in Oversampled: 8815
# Num in Oversampled: 8823
# Num in Oversampled: 8831
# Num in Oversampled: 8839
# Num in Oversampled: 8847
# Num in Oversampled: 8855
# Num in Oversampled: 8863
# Num in Oversampled: 8871
# Num in Oversampled: 8879
# Num in Oversampled: 8887
# Num in Oversampled: 8895
# Num in Oversampled: 8903
# Num in Oversampled: 8911
# Num in Oversampled: 8919
# Num in Oversampled: 8927
# Num in Oversampled: 8935
# Num in Oversampled: 8943
# Num in Oversampled: 8951
# Num in Oversampled: 8959
# Num in Oversampled: 8967
# Num in Oversampled: 8975
# Num in Oversampled: 8983
# Num in Oversampled: 8991
# Num in Oversampled: 8999
# Num in Oversampled: 9007
# Num in Oversampled: 9015
# Num in Oversampled: 9023
# Num in Oversampled: 9031
# Num in Oversampled: 9039
# Num in Oversampled: 9047
# Num in Oversampled: 9055
# Num in Oversampled: 9063
# Num in Oversampled: 9071
# Num in Oversampled: 9079
# Num in Oversampled: 9087
# Num in Oversampled: 9095
# Num in Oversampled: 9103
# Num in Oversampled: 9111
# Num in Oversampled: 9119
# Num in Oversampled: 9127
# Num in Oversampled: 9135
# Num in Oversampled: 9143
# Num in Oversampled: 9151
# Num in Oversampled: 9159
# Num in Oversampled: 9167
# Num in Oversampled: 9175
# Num in Oversampled: 9183
# Num in Oversampled: 9191
# Num in Oversampled: 9199
# Num in Oversampled: 9207
# Num in Oversampled: 9215
# Num in Oversampled: 9223
# Num in Oversampled: 9231
# Num in Oversampled: 9239
# Num in Oversampled: 9247
# Num in Oversampled: 9255
# Num in Oversampled: 9263
# Num in Oversampled: 9271
# Num in Oversampled: 9279
# Num in Oversampled: 9287
# Num in Oversampled: 9295
# Num in Oversampled: 9303
# Num in Oversampled: 9311
# Num in Oversampled: 9319
# Num in Oversampled: 9327
# Num in Oversampled: 9335
# Num in Oversampled: 9343
# Num in Oversampled: 9351
# Num in Oversampled: 9359
# Num in Oversampled: 9367
# Num in Oversampled: 9375
# Num in Oversampled: 9383
# Num in Oversampled: 9391
# Num in Oversampled: 9399
# Num in Oversampled: 9407
# Num in Oversampled: 9415
# Num in Oversampled: 9423
# Num in Oversampled: 9431
# Num in Oversampled: 9439
# Num in Oversampled: 9447
# Num in Oversampled: 9455
# Num in Oversampled: 9463
# Num in Oversampled: 9471
# Num in Oversampled: 9479
# Num in Oversampled: 9487
# Num in Oversampled: 9495
# Num in Oversampled: 9503
# Num in Oversampled: 9511
# Num in Oversampled: 9519
# Num in Oversampled: 9527
# Num in Oversampled: 9535
# Num in Oversampled: 9543
# Num in Oversampled: 9551
# Num in Oversampled: 9559
# Num in Oversampled: 9567
# Num in Oversampled: 9575
# Num in Oversampled: 9583
# Num in Oversampled: 9591
# Num in Oversampled: 9599
# Num in Oversampled: 9607
# Num in Oversampled: 9615
# Num in Oversampled: 9623
# Num in Oversampled: 9631
# Num in Oversampled: 9639
# Num in Oversampled: 9647
# Num in Oversampled: 9655
# Num in Oversampled: 9663
# Num in Oversampled: 9671
# Num in Oversampled: 9679
# Num in Oversampled: 9687
# Num in Oversampled: 9695
# Num in Oversampled: 9703
# Num in Oversampled: 9711
# Num in Oversampled: 9719
# Num in Oversampled: 9727
# Num in Oversampled: 9735
# Num in Oversampled: 9743
# Num in Oversampled: 9751
# Num in Oversampled: 9759
# Num in Oversampled: 9767
# Num in Oversampled: 9775
# Num in Oversampled: 9783
# Num in Oversampled: 9791
# Num in Oversampled: 9799
# Num in Oversampled: 9807
# Num in Oversampled: 9815
# Num in Oversampled: 9823
# Num in Oversampled: 9831
# Num in Oversampled: 9839
# Num in Oversampled: 9847
# Num in Oversampled: 9855
# Num in Oversampled: 9863
# Num in Oversampled: 9871
# Num in Oversampled: 9879
# Num in Oversampled: 9887
# Num in Oversampled: 9895
# Num in Oversampled: 9903
# Num in Oversampled: 9911
# Num in Oversampled: 9919
# Num in Oversampled: 9927
# Num in Oversampled: 9935
# Num in Oversampled: 9943
# Num in Oversampled: 9951
# Num in Oversampled: 9959
# Num in Oversampled: 9967
# Num in Oversampled: 9975
# Num in Oversampled: 9983
# Num in Oversampled: 9991
# Num in Oversampled: 9999
# Num in Oversampled: 10007
# Num in Oversampled: 10015
# Num in Oversampled: 10023
# Num in Oversampled: 10031
# Num in Oversampled: 10039
# Num in Oversampled: 10047
# Num in Oversampled: 10055
# Num in Oversampled: 10063
# Num in Oversampled: 10071
# Num in Oversampled: 10079
# Num in Oversampled: 10087
# Num in Oversampled: 10095
# Num in Oversampled: 10103
# Num in Oversampled: 10111
# Num in Oversampled: 10119
# Num in Oversampled: 10127
# Num in Oversampled: 10135
# Num in Oversampled: 10143
# Num in Oversampled: 10151
# Num in Oversampled: 10159
# Num in Oversampled: 10167
# Num in Oversampled: 10175
# Num in Oversampled: 10183
# Num in Oversampled: 10191
# Num in Oversampled: 10199
# Num in Oversampled: 10207
# Num in Oversampled: 10215
# Num in Oversampled: 10223
# Num in Oversampled: 10231
# Num in Oversampled: 10239
# Num in Oversampled: 10247
# Num in Oversampled: 10255
# Num in Oversampled: 10263
# Num in Oversampled: 10271
# Num in Oversampled: 10279
# Num in Oversampled: 10287
# Num in Oversampled: 10295
# Num in Oversampled: 10303
# Num in Oversampled: 10311
# Num in Oversampled: 10319
# Num in Oversampled: 10327
# Num in Oversampled: 10335
# Num in Oversampled: 10343
# Num in Oversampled: 10351
# Num in Oversampled: 10359
# Num in Oversampled: 10367
# Num in Oversampled: 10375
# Num in Oversampled: 10383
# Num in Oversampled: 10391
# Num in Oversampled: 10399
# Num in Oversampled: 10407
# Num in Oversampled: 10415
# Num in Oversampled: 10423
# Num in Oversampled: 10431
# Num in Oversampled: 10439
# Num in Oversampled: 10447
# Num in Oversampled: 10455
# Num in Oversampled: 10463
# Num in Oversampled: 10471
# Num in Oversampled: 10479
# Num in Oversampled: 10487
# Num in Oversampled: 10495
# Num in Oversampled: 10503
# Num in Oversampled: 10511
# Num in Oversampled: 10519
# Num in Oversampled: 10527
# Num in Oversampled: 10535
# Num in Oversampled: 10543
# Num in Oversampled: 10551
# Num in Oversampled: 10559
# Num in Oversampled: 10567
# Num in Oversampled: 10575
# Num in Oversampled: 10583
# Num in Oversampled: 10591
# Num in Oversampled: 10599
# Num in Oversampled: 10607
# Num in Oversampled: 10615
# Num in Oversampled: 10623
# Num in Oversampled: 10631
# Num in Oversampled: 10639
# Num in Oversampled: 10647
# Num in Oversampled: 10655
# Num in Oversampled: 10663
# Num in Oversampled: 10671
# Num in Oversampled: 10679
# Num in Oversampled: 10687
# Num in Oversampled: 10695
# Num in Oversampled: 10703
# Num in Oversampled: 10711
# Num in Oversampled: 10719
# Num in Oversampled: 10727
# Num in Oversampled: 10735
# Num in Oversampled: 10743
# Num in Oversampled: 10751
# Num in Oversampled: 10759
# Num in Oversampled: 10767
# Num in Oversampled: 10775
# Num in Oversampled: 10783
# Num in Oversampled: 10791
# Num in Oversampled: 10799
# Num in Oversampled: 10807
# Num in Oversampled: 10815
# Num in Oversampled: 10823
# Num in Oversampled: 10831
# Num in Oversampled: 10839
# Num in Oversampled: 10847
# Num in Oversampled: 10855
# Num in Oversampled: 10863
# Num in Oversampled: 10871
# Num in Oversampled: 10879
# Num in Oversampled: 10887
# Num in Oversampled: 10895
# Num in Oversampled: 10903
# Num in Oversampled: 10911
# Num in Oversampled: 10919
# Num in Oversampled: 10927
# Num in Oversampled: 10935
# Num in Oversampled: 10943
# Num in Oversampled: 10951
# Num in Oversampled: 10959
# Num in Oversampled: 10967
# Num in Oversampled: 10975
# Num in Oversampled: 10983
# Num in Oversampled: 10991
# Num in Oversampled: 10999
# Num in Oversampled: 11007
# Num in Oversampled: 11015
# Num in Oversampled: 11023
# Num in Oversampled: 11031
# Num in Oversampled: 11039
# Num in Oversampled: 11047
# Num in Oversampled: 11055
# Num in Oversampled: 11063
# Num in Oversampled: 11071
# Num in Oversampled: 11079
# Num in Oversampled: 11087
# Num in Oversampled: 11095
# Num in Oversampled: 11103
# Num in Oversampled: 11111
# Num in Oversampled: 11119
# Num in Oversampled: 11127
# Num in Oversampled: 11135
# Num in Oversampled: 11143
# Num in Oversampled: 11151
# Num in Oversampled: 11159
# Num in Oversampled: 11167
# Num in Oversampled: 11175
# Num in Oversampled: 11183
# Num in Oversampled: 11191
# Num in Oversampled: 11199
# Num in Oversampled: 11207
# Num in Oversampled: 11215
# Num in Oversampled: 11223
# Num in Oversampled: 11231
# Num in Oversampled: 11239
# Num in Oversampled: 11247
# Num in Oversampled: 11255
# Num in Oversampled: 11263
# Num in Oversampled: 11271
# Num in Oversampled: 11279
# Num in Oversampled: 11287
# Num in Oversampled: 11295
# Num in Oversampled: 11303
# Num in Oversampled: 11311
# Num in Oversampled: 11319
# Num in Oversampled: 11327
# Num in Oversampled: 11335
# Num in Oversampled: 11343
# Num in Oversampled: 11351
# Num in Oversampled: 11359
# Num in Oversampled: 11367
# Num in Oversampled: 11375
# Num in Oversampled: 11383
# Num in Oversampled: 11391
# Num in Oversampled: 11399
# Num in Oversampled: 11407
# Num in Oversampled: 11415
# Num in Oversampled: 11423
# Num in Oversampled: 11431
# Num in Oversampled: 11439
# Num in Oversampled: 11447
# Num in Oversampled: 11455
# Num in Oversampled: 11463
# Num in Oversampled: 11471
# Num in Oversampled: 11479
# Num in Oversampled: 11487
# Num in Oversampled: 11495
# Num in Oversampled: 11503
# Num in Oversampled: 11511
# Num in Oversampled: 11519
# Num in Oversampled: 11527
# Num in Oversampled: 11535
# Num in Oversampled: 11543
# Num in Oversampled: 11551
# Num in Oversampled: 11559
# Num in Oversampled: 11567
# Num in Oversampled: 11575
# Num in Oversampled: 11583
# Num in Oversampled: 11591
# Num in Oversampled: 11599
# Num in Oversampled: 11607
# Num in Oversampled: 11615
# Num in Oversampled: 11623
# Num in Oversampled: 11631
# Num in Oversampled: 11639
# Num in Oversampled: 11647
# Num in Oversampled: 11655
# Num in Oversampled: 11663
# Num in Oversampled: 11671
# Num in Oversampled: 11679
# Num in Oversampled: 11687
# Num in Oversampled: 11695
# Num in Oversampled: 11703
# Num in Oversampled: 11711
# Num in Oversampled: 11719
# Num in Oversampled: 11727
# Num in Oversampled: 11735
# Num in Oversampled: 11743
# Num in Oversampled: 11751
# Num in Oversampled: 11759
# Num in Oversampled: 11767
# Num in Oversampled: 11775
# Num in Oversampled: 11783
# Num in Oversampled: 11791
# Num in Oversampled: 11799
# Num in Oversampled: 11807
# Num in Oversampled: 11815
# Num in Oversampled: 11823
# Num in Oversampled: 11831
# Num in Oversampled: 11839
# Num in Oversampled: 11847
# Num in Oversampled: 11855
# Num in Oversampled: 11863
# Num in Oversampled: 11871
# Num in Oversampled: 11879
# Num in Oversampled: 11887
# Num in Oversampled: 11895
# Num in Oversampled: 11903
# Num in Oversampled: 11911
# Num in Oversampled: 11919
# Num in Oversampled: 11927
# Num in Oversampled: 11935
# Num in Oversampled: 11943
# Num in Oversampled: 11951
# Num in Oversampled: 11959
# Num in Oversampled: 11967
# Num in Oversampled: 11975
# Num in Oversampled: 11983
# Num in Oversampled: 11991
# Num in Oversampled: 11999
# Num in Oversampled: 12007
# Num in Oversampled: 12015
# Num in Oversampled: 12023
# Num in Oversampled: 12031
# Num in Oversampled: 12039
# Num in Oversampled: 12047
# Num in Oversampled: 12055
# Num in Oversampled: 12063
# Num in Oversampled: 12071
# Num in Oversampled: 12079
# Num in Oversampled: 12087
# Num in Oversampled: 12095
# Num in Oversampled: 12103
# Num in Oversampled: 12111
# Num in Oversampled: 12119
# Num in Oversampled: 12127
# Num in Oversampled: 12135
# Num in Oversampled: 12143
# Num in Oversampled: 12151
# Num in Oversampled: 12159
# Num in Oversampled: 12167
# Num in Oversampled: 12175
# Num in Oversampled: 12183
# Num in Oversampled: 12191
# Num in Oversampled: 12199
# Num in Oversampled: 12207
# Num in Oversampled: 12215
# Num in Oversampled: 12223
# Num in Oversampled: 12231
# Num in Oversampled: 12239
# Num in Oversampled: 12247
# Num in Oversampled: 12255
# Num in Oversampled: 12263
# Num in Oversampled: 12271
# Num in Oversampled: 12279
# Num in Oversampled: 12287
# Num in Oversampled: 12295
# Num in Oversampled: 12303
# Num in Oversampled: 12311
# Num in Oversampled: 12319
# Num in Oversampled: 12327
# Num in Oversampled: 12335
# Num in Oversampled: 12343
# Num in Oversampled: 12351
# Num in Oversampled: 12359
# Num in Oversampled: 12367
# Num in Oversampled: 12375
# Num in Oversampled: 12383
# Num in Oversampled: 12391
# Num in Oversampled: 12399
# Num in Oversampled: 12407
# Num in Oversampled: 12415
# Num in Oversampled: 12423
# Num in Oversampled: 12431
# Num in Oversampled: 12439
# Num in Oversampled: 12447
# Num in Oversampled: 12455
# Num in Oversampled: 12463
# Num in Oversampled: 12471
# Num in Oversampled: 12479
# Num in Oversampled: 12487
# Num in Oversampled: 12495
# Num in Oversampled: 12503
# Num in Oversampled: 12511
# Num in Oversampled: 12519
# Num in Oversampled: 12527
# Num in Oversampled: 12535
# Num in Oversampled: 12543
# Num in Oversampled: 12551
# Num in Oversampled: 12559
# Num in Oversampled: 12567
# Num in Oversampled: 12575
# Num in Oversampled: 12583
# Num in Oversampled: 12591
# Num in Oversampled: 12599
# Num in Oversampled: 12607
# Num in Oversampled: 12615
# Num in Oversampled: 12623
# Num in Oversampled: 12631
# Num in Oversampled: 12639
# Num in Oversampled: 12647
# Num in Oversampled: 12655
# Num in Oversampled: 12663
# Num in Oversampled: 12671
# Num in Oversampled: 12679
# Num in Oversampled: 12687
# Num in Oversampled: 12695
# Num in Oversampled: 12703
# Num in Oversampled: 12711
# Num in Oversampled: 12719
# Num in Oversampled: 12727
# Num in Oversampled: 12735
# Num in Oversampled: 12743
# Num in Oversampled: 12751
# Num in Oversampled: 12759
# Num in Oversampled: 12767
# Num in Oversampled: 12775
# Num in Oversampled: 12783
# Num in Oversampled: 12791
# Num in Oversampled: 12799
# Num in Oversampled: 12807
# Num in Oversampled: 12815
# Num in Oversampled: 12823
# Num in Oversampled: 12831
# Num in Oversampled: 12839
# Num in Oversampled: 12847
# Num in Oversampled: 12855
# Num in Oversampled: 12863
# Num in Oversampled: 12871
# Num in Oversampled: 12879
# Num in Oversampled: 12887
# Num in Oversampled: 12895
# Num in Oversampled: 12903
# Num in Oversampled: 12911
# Num in Oversampled: 12919
# Num in Oversampled: 12927
# Num in Oversampled: 12935
# Num in Oversampled: 12943
# Num in Oversampled: 12951
# Num in Oversampled: 12959
# Num in Oversampled: 12967
# Num in Oversampled: 12975
# Num in Oversampled: 12983
# Num in Oversampled: 12991
# Num in Oversampled: 12999
# Num in Oversampled: 13007
# Num in Oversampled: 13015
# Num in Oversampled: 13023
# Num in Oversampled: 13031
# Num in Oversampled: 13039
# Num in Oversampled: 13047
# Num in Oversampled: 13055
# Num in Oversampled: 13063
# Num in Oversampled: 13071
# Num in Oversampled: 13079
# Num in Oversampled: 13087
# Num in Oversampled: 13095
# Num in Oversampled: 13103
# Num in Oversampled: 13111
# Num in Oversampled: 13119
# Num in Oversampled: 13127
# Num in Oversampled: 13135
# Num in Oversampled: 13143
# Num in Oversampled: 13151
# Num in Oversampled: 13159
# Num in Oversampled: 13167
# Num in Oversampled: 13175
# Num in Oversampled: 13183
# Num in Oversampled: 13191
# Num in Oversampled: 13199
# Num in Oversampled: 13207
# Num in Oversampled: 13215
# Num in Oversampled: 13223
# Num in Oversampled: 13231
# Num in Oversampled: 13239
# Num in Oversampled: 13247
# Num in Oversampled: 13255
# Num in Oversampled: 13263
# Num in Oversampled: 13271
# Num in Oversampled: 13279
# Num in Oversampled: 13287
# Num in Oversampled: 13295
# Num in Oversampled: 13303
# Num in Oversampled: 13311
# Num in Oversampled: 13319
# Num in Oversampled: 13327
# Num in Oversampled: 13335
# Num in Oversampled: 13343
# Num in Oversampled: 13351
# Num in Oversampled: 13359
# Num in Oversampled: 13367
# Num in Oversampled: 13375
# Num in Oversampled: 13383
# Num in Oversampled: 13391
# Num in Oversampled: 13399
# Num in Oversampled: 13407
# Num in Oversampled: 13415
# Num in Oversampled: 13423
# Num in Oversampled: 13431
# Num in Oversampled: 13439
# Num in Oversampled: 13447
# Num in Oversampled: 13455
# Num in Oversampled: 13463
# Num in Oversampled: 13471
# Num in Oversampled: 13479
# Num in Oversampled: 13487
# Num in Oversampled: 13495
# Num in Oversampled: 13503
# Num in Oversampled: 13511
# Num in Oversampled: 13519
# Num in Oversampled: 13527
# Num in Oversampled: 13535
# Num in Oversampled: 13543
# Num in Oversampled: 13551
# Num in Oversampled: 13559
# Num in Oversampled: 13567
# Num in Oversampled: 13575
# Num in Oversampled: 13583
# Num in Oversampled: 13591
# Num in Oversampled: 13599
# Num in Oversampled: 13607
# Num in Oversampled: 13615
# Num in Oversampled: 13623
# Num in Oversampled: 13631
# Num in Oversampled: 13639
# Num in Oversampled: 13647
# Num in Oversampled: 13655
# Num in Oversampled: 13663
# Num in Oversampled: 13671
# Num in Oversampled: 13679
# Num in Oversampled: 13687
# Num in Oversampled: 13695
# Num in Oversampled: 13703
# Num in Oversampled: 13711
# Num in Oversampled: 13719
# Num in Oversampled: 13727
# Num in Oversampled: 13735
# Num in Oversampled: 13743
# Num in Oversampled: 13751
# Num in Oversampled: 13759
# Num in Oversampled: 13767
# Num in Oversampled: 13775
# Num in Oversampled: 13783
# Num in Oversampled: 13791
# Num in Oversampled: 13799
# Num in Oversampled: 13807
# Num in Oversampled: 13815
# Num in Oversampled: 13823
# Num in Oversampled: 13831
# Num in Oversampled: 13839
# Num in Oversampled: 13847
# Num in Oversampled: 13855
# Num in Oversampled: 13863
# Num in Oversampled: 13871
# Num in Oversampled: 13879
# Num in Oversampled: 13887
# Num in Oversampled: 13895
# Num in Oversampled: 13903
# Num in Oversampled: 13911
# Num in Oversampled: 13919
# Num in Oversampled: 13927
# Num in Oversampled: 13935
# Num in Oversampled: 13943
# Num in Oversampled: 13951
# Num in Oversampled: 13959
# Num in Oversampled: 13967
# Num in Oversampled: 13975
# Num in Oversampled: 13983
# Num in Oversampled: 13991
# Num in Oversampled: 13999
# 1000:1
#               precision    recall  f1-score   support
#
#          red       0.00      1.00      0.01         2
#         blue       1.00      0.85      0.92      3001
#
#     accuracy                           0.85      3003
#    macro avg       0.50      0.92      0.46      3003
# weighted avg       1.00      0.85      0.92      3003
#
# For dataset 1, numClass0=74, imbalance=95.0
# Num in Oversampled: 7070
# Num in Oversampled: 7144
# Num in Oversampled: 7218
# Num in Oversampled: 7292
# Num in Oversampled: 7366
# Num in Oversampled: 7440
# Num in Oversampled: 7514
# Num in Oversampled: 7588
# Num in Oversampled: 7662
# Num in Oversampled: 7736
# Num in Oversampled: 7810
# Num in Oversampled: 7884
# Num in Oversampled: 7958
# Num in Oversampled: 8032
# Num in Oversampled: 8106
# Num in Oversampled: 8180
# Num in Oversampled: 8254
# Num in Oversampled: 8328
# Num in Oversampled: 8402
# Num in Oversampled: 8476
# Num in Oversampled: 8550
# Num in Oversampled: 8624
# Num in Oversampled: 8698
# Num in Oversampled: 8772
# Num in Oversampled: 8846
# Num in Oversampled: 8920
# Num in Oversampled: 8994
# Num in Oversampled: 9068
# Num in Oversampled: 9142
# Num in Oversampled: 9216
# Num in Oversampled: 9290
# Num in Oversampled: 9364
# Num in Oversampled: 9438
# Num in Oversampled: 9512
# Num in Oversampled: 9586
# Num in Oversampled: 9660
# Num in Oversampled: 9734
# Num in Oversampled: 9808
# Num in Oversampled: 9882
# Num in Oversampled: 9956
# Num in Oversampled: 10030
# Num in Oversampled: 10104
# Num in Oversampled: 10178
# Num in Oversampled: 10252
# Num in Oversampled: 10326
# Num in Oversampled: 10400
# Num in Oversampled: 10474
# Num in Oversampled: 10548
# Num in Oversampled: 10622
# Num in Oversampled: 10696
# Num in Oversampled: 10770
# Num in Oversampled: 10844
# Num in Oversampled: 10918
# Num in Oversampled: 10992
# Num in Oversampled: 11066
# Num in Oversampled: 11140
# Num in Oversampled: 11214
# Num in Oversampled: 11288
# Num in Oversampled: 11362
# Num in Oversampled: 11436
# Num in Oversampled: 11510
# Num in Oversampled: 11584
# Num in Oversampled: 11658
# Num in Oversampled: 11732
# Num in Oversampled: 11806
# Num in Oversampled: 11880
# Num in Oversampled: 11954
# Num in Oversampled: 12028
# Num in Oversampled: 12102
# Num in Oversampled: 12176
# Num in Oversampled: 12250
# Num in Oversampled: 12324
# Num in Oversampled: 12398
# Num in Oversampled: 12472
# Num in Oversampled: 12546
# Num in Oversampled: 12620
# Num in Oversampled: 12694
# Num in Oversampled: 12768
# Num in Oversampled: 12842
# Num in Oversampled: 12916
# Num in Oversampled: 12990
# Num in Oversampled: 13064
# Num in Oversampled: 13138
# Num in Oversampled: 13212
# Num in Oversampled: 13286
# Num in Oversampled: 13360
# Num in Oversampled: 13434
# Num in Oversampled: 13508
# Num in Oversampled: 13582
# Num in Oversampled: 13656
# Num in Oversampled: 13730
# Num in Oversampled: 13804
# Num in Oversampled: 13878
# Num in Oversampled: 13952
# Num in Oversampled: 14026
# 100:1
#               precision    recall  f1-score   support
#
#          red       0.05      0.88      0.09        26
#         blue       1.00      0.85      0.92      3004
#
#     accuracy                           0.85      3030
#    macro avg       0.52      0.87      0.51      3030
# weighted avg       0.99      0.85      0.91      3030
#
# For dataset 2, numClass0=711, imbalance=10.0
# Num in Oversampled: 7700
# Num in Oversampled: 8411
# Num in Oversampled: 9122
# Num in Oversampled: 9833
# Num in Oversampled: 10544
# Num in Oversampled: 11255
# Num in Oversampled: 11966
# Num in Oversampled: 12677
# Num in Oversampled: 13388
# Num in Oversampled: 14099
# 10:1
#               precision    recall  f1-score   support
#
#          red       0.38      0.85      0.53       289
#         blue       0.98      0.87      0.92      3011
#
#     accuracy                           0.87      3300
#    macro avg       0.68      0.86      0.72      3300
# weighted avg       0.93      0.87      0.89      3300
#
# For dataset 3, numClass0=7000, imbalance=1.0
# Num in Oversampled: 14000
# 1:1
#               precision    recall  f1-score   support
#
#          red       0.87      0.87      0.87      3000
#         blue       0.87      0.87      0.87      3000
#
#     accuracy                           0.87      6000
#    macro avg       0.87      0.87      0.87      6000
# weighted avg       0.87      0.87      0.87      6000

# %% [markdown]
# ## Discussion2
# - Which was more successful, under- or over-sampling?
# - What other ways could you combat class imbalance?
# - Which performance metrics would you use?
#
# ---
#
# ### Bonus: Synthetic Minority Oversampling Technique (SMOTE)
#
# SMOTE-variants

# %%
# !pip install smote-variants
# Out:
# Requirement already satisfied: smote-variants in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: statistics in /usr/local/lib/python3.6/dist-packages (from smote-variants) (1.0.3.5)
# Requirement already satisfied: mkl in /usr/local/lib/python3.6/dist-packages (from smote-variants) (2019.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from smote-variants) (0.22.2.post1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from smote-variants) (0.17.0)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from smote-variants) (1.18.5)
# Requirement already satisfied: minisom in /usr/local/lib/python3.6/dist-packages (from smote-variants) (2.2.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from smote-variants) (1.4.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (from smote-variants) (2.3.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from smote-variants) (2.4.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from smote-variants) (1.1.4)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.6/dist-packages (from statistics->smote-variants) (0.16)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.6/dist-packages (from mkl->smote-variants) (2020.0.133)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (3.12.4)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (0.35.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (1.12.1)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (0.3.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (3.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (1.6.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (0.10.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (2.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (1.33.2)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (1.1.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->smote-variants) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->smote-variants) (3.13)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->smote-variants) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->smote-variants) (2018.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow->smote-variants) (50.3.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow->smote-variants) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow->smote-variants) (0.4.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow->smote-variants) (1.7.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow->smote-variants) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow->smote-variants) (1.17.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow->smote-variants) (3.3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (4.6)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow->smote-variants) (3.4.0)

# %%
import matplotlib.pyplot as plt
import smote_variants as sv
from sklearn.datasets import load_wine

wine_bunch = load_wine()

X, y= wine_bunch['data'], wine_bunch['target']

oversampler= sv.MulticlassOversampling(sv.distance_SMOTE())

# X_samp and y_samp contain the oversampled dataset
X_samp, y_samp= oversampler.sample(X, y)
plt.scatter(X[:,0], X[:,1], alpha=0.3, c=y, cmap='viridis')
plt.title(f'num total: {len(X)}')
# Out:
# 2020-11-20 16:25:48,213:INFO:MulticlassOversampling: Running multiclass oversampling with strategy eq_1_vs_many_successive
# 2020-11-20 16:25:48,220:INFO:MulticlassOversampling: Sampling minority class with label: 0
# 2020-11-20 16:25:48,221:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': None}")
# 2020-11-20 16:25:48,227:INFO:MulticlassOversampling: Sampling minority class with label: 2
# 2020-11-20 16:25:48,230:INFO:distance_SMOTE: Running sampling via ('distance_SMOTE', "{'proportion': 0.24468085106382978, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': None}")
# Text(0.5, 1.0, 'num total: 178')

# %%
plt.scatter(X_samp[:,0], X_samp[:,1], alpha=1, c=y_samp, cmap='viridis')
plt.title(f'num total: {len(X)}')
# Out:
# Text(0.5, 1.0, 'num total: 178')

# %% [markdown]
# ### Excitingly: There are a tremendous number of techniques available!
#
# The implemented techniques: [SMOTE] , [SMOTE_TomekLinks] , [SMOTE_ENN] , [Borderline_SMOTE1] , [Borderline_SMOTE2] , [ADASYN] , [AHC] , [LLE_SMOTE] , [distance_SMOTE] , [SMMO] , [polynom_fit_SMOTE] , [Stefanowski] , [ADOMS] , [Safe_Level_SMOTE] , [MSMOTE] , [DE_oversampling] , [SMOBD] , [SUNDO] , [MSYN] , [SVM_balance] , [TRIM_SMOTE] , [SMOTE_RSB] , [ProWSyn] , [SL_graph_SMOTE] , [NRSBoundary_SMOTE] , [LVQ_SMOTE] , [SOI_CJ] , [ROSE] , [SMOTE_OUT] , [SMOTE_Cosine] , [Selected_SMOTE] , [LN_SMOTE] , [MWMOTE] , [PDFOS] , [IPADE_ID] , [RWO_sampling] , [NEATER] , [DEAGO] , [Gazzah] , [MCT] , [ADG] , [SMOTE_IPF] , [KernelADASYN] , [MOT2LD] , [V_SYNTH] , [OUPS] , [SMOTE_D] , [SMOTE_PSO] , [CURE_SMOTE] , [SOMO] , [ISOMAP_Hybrid] , [CE_SMOTE] , [Edge_Det_SMOTE] , [CBSO] , [E_SMOTE] , [DBSMOTE] , [ASMOBD] , [Assembled_SMOTE] , [SDSMOTE] , [DSMOTE] , [G_SMOTE] , [NT_SMOTE] , [Lee] , [SPY] , [SMOTE_PSOBAT] , [MDO] , [Random_SMOTE] , [ISMOTE] , [VIS_RST] , [GASMOTE] , [A_SUWO] , [SMOTE_FRST_2T] , [AND_SMOTE] , [NRAS] , [AMSCO] , [SSO] , [NDO_sampling] , [DSRBF] , [Gaussian_SMOTE] , [kmeans_SMOTE] , [Supervised_SMOTE] , [SN_SMOTE] , [CCR] , [ANS] , [cluster_SMOTE]
#
#
# ---
#
# ## Part II: k-Means Implementation in Python

# %%
# Import necessary libraries
from copy import deepcopy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
from IPython.display import clear_output

# Set three centers, the model should predict similar results
center_1 = np.array([1,1])
center_2 = np.array([5,5])
center_3 = np.array([8,1])

# Generate random data and center it to the three centers
data_1 = np.random.randn(200, 2) + center_1
data_2 = np.random.randn(200,2) + center_2
data_3 = np.random.randn(200,2) + center_3

data = np.concatenate((data_1, data_2, data_3), axis = 0)

plt.scatter(data[:,0], data[:,1], s=7)

# %%
# Number of clusters
k = 3
# Number of training data
n = data.shape[0]
# Number of features in the data
c = data.shape[1]

# Generate random centers, here we use sigma and mean to ensure it represent the whole data
mean = np.mean(data, axis = 0)
std = np.std(data, axis = 0)
centers = np.random.randn(k,c)*std + mean

# Plot the data and the centers generated as random
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(centers[:,0], centers[:,1], marker='*', c='g', s=150)

# %%
centers_old = np.zeros(centers.shape) # to store old centers
centers_new = deepcopy(centers) # Store new centers

data.shape
clusters = np.zeros(n)
distances = np.zeros((n,k))

error = np.linalg.norm(centers_new - centers_old)

# When, after an update, the estimate of that center stays the same, exit loop
while error != 0:
    # Measure the distance to every center
    for i in range(k):
        distances[:,i] = np.linalg.norm(data - centers[i], axis=1)
    # Assign all training data to closest center
    clusters = np.argmin(distances, axis = 1)
    
    centers_old = deepcopy(centers_new)
    # Calculate mean for every cluster and update the center
    for i in range(k):
        centers_new[i] = np.mean(data[clusters == i], axis=0)
        clear_output
        plt.scatter(data[:,0], data[:,1], s=7)
        plt.scatter(centers_new[:,0], centers_new[:,1], marker='*', c='g', s=150)
    error = np.linalg.norm(centers_new - centers_old)
centers_new
# Out:
# array([[-0.17208063,  0.82278181],
#        [ 1.72669626,  1.40954896],
#        [ 6.71814288,  2.90245287]])

# %%
# Plot the data and the centers generated as random
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(centers_new[:,0], centers_new[:,1], marker='*', c='g', s=150)

# %% [markdown]
# #FIN
